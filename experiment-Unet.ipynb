# %% [markdown]
# # Experiment Unet
# #### Setup:
# **Dataset**: 3 different types of brain tumors <br>
# **Loss function**: Dice loss <br>
# **Optimizer**: Adam <br>
# **Model**: UNet

# %%
# Imports and training parameters
import torch
from torchvision.transforms import transforms
from src.datasets import BrainTumorDatasetMask
from src.loss import  dice_loss
from src.metrics import dice_coeff
from src.models import  UNet
from src.trainers import Trainer
torch.manual_seed(0)
num_epochs = 100
batch_size = 2
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Data preparation
# load the data see data_preprocessing notebook for more explanation

def normalize(x,  mean=470, std=None):
    mean_tansor = torch.ones_like(x) * mean
    x -= mean_tansor
    if std:
        x /= std
    return x

def preprocessing(image, mask):
    mask_transformer = transforms.Compose([
        transforms.ToTensor()    
    ])

    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: normalize(x))
    ])
    return image_transformer(image).float(), mask_transformer(mask).float()

target_folder = './data/'
ds_train = BrainTumorDatasetMask(root=target_folder, train=True, transform=preprocessing)
ds_test = BrainTumorDatasetMask(root=target_folder, train=False, transform=preprocessing)
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=True)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size, shuffle=False)
# Out:
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script

# %%
# Training and evaluation
model = UNet()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = dice_loss
success_metric = dice_coeff
trainer = Trainer(model, criterion, optimizer, dice_coeff, device, None)
fit_res = trainer.fit(dl_train, 
                      dl_test,
                      num_epochs= num_epochs,
                      checkpoints='src/saved_models/' + model.__class__.__name__)
# Out:
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 0.893, Min 0.491, Max 1.000), (Avg. Score 0.1088, Min 0.0000, Max 0.5394): 100%|██████████| 1296/1296 [09:21<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.987, Min 0.775, Max 1.000), (Avg. Score 0.0117, Min 0.0000, Max 0.2172): 100%|██████████| 229/229 [00:36<00:00,  6.31it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 0.851, Min 0.390, Max 1.000), (Avg. Score 0.1497, Min 0.0000, Max 0.6132): 100%|██████████| 1296/1296 [09:22<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.968, Min 0.873, Max 1.000), (Avg. Score 0.0322, Min 0.0000, Max 0.1275): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# **** Checkpoint saved ****
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 0.784, Min 0.165, Max 1.000), (Avg. Score 0.2169, Min 0.0000, Max 0.8404): 100%|██████████| 1296/1296 [09:22<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.954, Min 0.313, Max 1.000), (Avg. Score 0.0455, Min 0.0000, Max 0.6876): 100%|██████████| 229/229 [00:36<00:00,  6.20it/s]
# **** Checkpoint saved ****
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 0.726, Min 0.142, Max 1.000), (Avg. Score 0.2744, Min 0.0000, Max 0.8612): 100%|██████████| 1296/1296 [09:23<00:00,  2.27it/s]
# test_batch (Avg. Loss 0.950, Min 0.446, Max 1.000), (Avg. Score 0.0501, Min 0.0000, Max 0.5548): 100%|██████████| 229/229 [00:37<00:00,  6.19it/s]
# **** Checkpoint saved ****
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 0.692, Min 0.107, Max 1.000), (Avg. Score 0.3088, Min 0.0000, Max 0.8942): 100%|██████████| 1296/1296 [09:23<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.859, Min 0.187, Max 1.000), (Avg. Score 0.1411, Min 0.0000, Max 0.8195): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# **** Checkpoint saved ****
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 0.623, Min 0.089, Max 1.000), (Avg. Score 0.3775, Min 0.0000, Max 0.9134): 100%|██████████| 1296/1296 [09:23<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.869, Min 0.155, Max 1.000), (Avg. Score 0.1308, Min 0.0000, Max 0.8476): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 0.577, Min 0.069, Max 1.000), (Avg. Score 0.4235, Min 0.0000, Max 0.9321): 100%|██████████| 1296/1296 [09:23<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.774, Min 0.111, Max 1.000), (Avg. Score 0.2260, Min 0.0000, Max 0.8901): 100%|██████████| 229/229 [00:36<00:00,  6.24it/s]
# **** Checkpoint saved ****
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 0.525, Min 0.070, Max 1.000), (Avg. Score 0.4749, Min 0.0000, Max 0.9321): 100%|██████████| 1296/1296 [09:23<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.676, Min 0.127, Max 1.000), (Avg. Score 0.3241, Min 0.0000, Max 0.8765): 100%|██████████| 229/229 [00:37<00:00,  7.03it/s]
# **** Checkpoint saved ****
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 0.510, Min 0.066, Max 1.000), (Avg. Score 0.4906, Min 0.0000, Max 0.9339): 100%|██████████| 1296/1296 [09:23<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.663, Min 0.098, Max 1.000), (Avg. Score 0.3370, Min 0.0000, Max 0.9034): 100%|██████████| 229/229 [00:36<00:00,  6.22it/s]
# **** Checkpoint saved ****
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 0.489, Min 0.061, Max 1.000), (Avg. Score 0.5108, Min 0.0000, Max 0.9398): 100%|██████████| 1296/1296 [09:23<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.604, Min 0.089, Max 1.000), (Avg. Score 0.3960, Min 0.0000, Max 0.9122): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# **** Checkpoint saved ****
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.469, Min 0.060, Max 1.000), (Avg. Score 0.5313, Min 0.0000, Max 0.9405): 100%|██████████| 1296/1296 [09:24<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.730, Min 0.187, Max 1.000), (Avg. Score 0.2700, Min 0.0000, Max 0.8158): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 0.443, Min 0.037, Max 1.000), (Avg. Score 0.5568, Min 0.0000, Max 0.9629): 100%|██████████| 1296/1296 [09:24<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.642, Min 0.097, Max 1.000), (Avg. Score 0.3585, Min 0.0000, Max 0.9034): 100%|██████████| 229/229 [00:37<00:00,  6.06it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 0.424, Min 0.045, Max 1.000), (Avg. Score 0.5761, Min 0.0000, Max 0.9551): 100%|██████████| 1296/1296 [09:24<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.642, Min 0.085, Max 1.000), (Avg. Score 0.3578, Min 0.0000, Max 0.9148): 100%|██████████| 229/229 [00:36<00:00,  6.93it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.421, Min 0.036, Max 1.000), (Avg. Score 0.5791, Min 0.0000, Max 0.9646): 100%|██████████| 1296/1296 [09:23<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.443, Min 0.052, Max 1.000), (Avg. Score 0.5575, Min 0.0000, Max 0.9481): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# **** Checkpoint saved ****
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.397, Min 0.033, Max 1.000), (Avg. Score 0.6034, Min 0.0000, Max 0.9669): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.403, Min 0.071, Max 1.000), (Avg. Score 0.5972, Min 0.0000, Max 0.9302): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# **** Checkpoint saved ****
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.387, Min 0.032, Max 1.000), (Avg. Score 0.6127, Min 0.0000, Max 0.9682): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.428, Min 0.042, Max 1.000), (Avg. Score 0.5720, Min 0.0000, Max 0.9587): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.376, Min 0.032, Max 1.000), (Avg. Score 0.6246, Min 0.0000, Max 0.9676): 100%|██████████| 1296/1296 [09:24<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.466, Min 0.049, Max 1.000), (Avg. Score 0.5343, Min 0.0000, Max 0.9511): 100%|██████████| 229/229 [00:36<00:00,  6.21it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.373, Min 0.031, Max 1.000), (Avg. Score 0.6268, Min 0.0000, Max 0.9691): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.467, Min 0.055, Max 1.000), (Avg. Score 0.5332, Min 0.0000, Max 0.9464): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.363, Min 0.021, Max 1.000), (Avg. Score 0.6367, Min 0.0000, Max 0.9790): 100%|██████████| 1296/1296 [09:24<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.465, Min 0.062, Max 1.000), (Avg. Score 0.5355, Min 0.0000, Max 0.9376): 100%|██████████| 229/229 [00:36<00:00,  6.20it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.341, Min 0.033, Max 1.000), (Avg. Score 0.6593, Min 0.0000, Max 0.9674): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.389, Min 0.053, Max 1.000), (Avg. Score 0.6112, Min 0.0000, Max 0.9472): 100%|██████████| 229/229 [00:37<00:00,  6.19it/s]
# **** Checkpoint saved ****
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.345, Min 0.026, Max 0.976), (Avg. Score 0.6552, Min 0.0240, Max 0.9746): 100%|██████████| 1296/1296 [09:24<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.467, Min 0.046, Max 1.000), (Avg. Score 0.5327, Min 0.0000, Max 0.9541): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.331, Min 0.026, Max 1.000), (Avg. Score 0.6686, Min 0.0000, Max 0.9740): 100%|██████████| 1296/1296 [09:24<00:00,  2.26it/s]
# test_batch (Avg. Loss 0.448, Min 0.057, Max 1.000), (Avg. Score 0.5525, Min 0.0000, Max 0.9429): 100%|██████████| 229/229 [00:36<00:00,  6.24it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.314, Min 0.024, Max 1.000), (Avg. Score 0.6862, Min 0.0000, Max 0.9764): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.350, Min 0.043, Max 1.000), (Avg. Score 0.6504, Min 0.0000, Max 0.9568): 100%|██████████| 229/229 [00:37<00:00,  6.09it/s]
# **** Checkpoint saved ****
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.305, Min 0.026, Max 1.000), (Avg. Score 0.6950, Min 0.0000, Max 0.9746): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.475, Min 0.044, Max 1.000), (Avg. Score 0.5254, Min 0.0000, Max 0.9555): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.304, Min 0.029, Max 1.000), (Avg. Score 0.6960, Min 0.0000, Max 0.9709): 100%|██████████| 1296/1296 [09:24<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.439, Min 0.046, Max 1.000), (Avg. Score 0.5611, Min 0.0000, Max 0.9538): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.292, Min 0.021, Max 1.000), (Avg. Score 0.7077, Min 0.0000, Max 0.9791): 100%|██████████| 1296/1296 [09:23<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.375, Min 0.046, Max 1.000), (Avg. Score 0.6252, Min 0.0000, Max 0.9539): 100%|██████████| 229/229 [00:37<00:00,  6.17it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.287, Min 0.027, Max 0.994), (Avg. Score 0.7131, Min 0.0055, Max 0.9727): 100%|██████████| 1296/1296 [09:24<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.348, Min 0.049, Max 1.000), (Avg. Score 0.6521, Min 0.0000, Max 0.9509): 100%|██████████| 229/229 [00:37<00:00,  6.17it/s]
# **** Checkpoint saved ****
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.275, Min 0.026, Max 1.000), (Avg. Score 0.7251, Min 0.0000, Max 0.9741): 100%|██████████| 1296/1296 [09:24<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.451, Min 0.048, Max 1.000), (Avg. Score 0.5492, Min 0.0000, Max 0.9523): 100%|██████████| 229/229 [00:37<00:00,  6.07it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.273, Min 0.025, Max 0.973), (Avg. Score 0.7269, Min 0.0268, Max 0.9753): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.548, Min 0.045, Max 1.000), (Avg. Score 0.4526, Min 0.0000, Max 0.9544): 100%|██████████| 229/229 [00:37<00:00,  6.18it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.264, Min 0.025, Max 1.000), (Avg. Score 0.7365, Min 0.0000, Max 0.9754): 100%|██████████| 1296/1296 [09:24<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.352, Min 0.053, Max 1.000), (Avg. Score 0.6481, Min 0.0000, Max 0.9472): 100%|██████████| 229/229 [00:36<00:00,  6.22it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.258, Min 0.026, Max 1.000), (Avg. Score 0.7422, Min 0.0000, Max 0.9740): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.391, Min 0.052, Max 1.000), (Avg. Score 0.6090, Min 0.0000, Max 0.9480): 100%|██████████| 229/229 [00:37<00:00,  6.55it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.256, Min 0.026, Max 1.000), (Avg. Score 0.7436, Min 0.0000, Max 0.9735): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.309, Min 0.047, Max 1.000), (Avg. Score 0.6916, Min 0.0000, Max 0.9528): 100%|██████████| 229/229 [00:37<00:00,  6.05it/s]
# **** Checkpoint saved ****
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.249, Min 0.021, Max 0.940), (Avg. Score 0.7513, Min 0.0622, Max 0.9788): 100%|██████████| 1296/1296 [09:25<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.330, Min 0.044, Max 1.000), (Avg. Score 0.6698, Min 0.0000, Max 0.9564): 100%|██████████| 229/229 [00:37<00:00,  6.07it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.242, Min 0.024, Max 1.000), (Avg. Score 0.7583, Min 0.0000, Max 0.9759): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.266, Min 0.034, Max 1.000), (Avg. Score 0.7343, Min 0.0000, Max 0.9664): 100%|██████████| 229/229 [00:37<00:00,  6.18it/s]
# **** Checkpoint saved ****
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.241, Min 0.023, Max 1.000), (Avg. Score 0.7592, Min 0.0000, Max 0.9766): 100%|██████████| 1296/1296 [09:24<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.333, Min 0.046, Max 1.000), (Avg. Score 0.6668, Min 0.0000, Max 0.9537): 100%|██████████| 229/229 [00:37<00:00,  6.08it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.240, Min 0.016, Max 0.934), (Avg. Score 0.7596, Min 0.0662, Max 0.9839): 100%|██████████| 1296/1296 [09:24<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.338, Min 0.043, Max 1.000), (Avg. Score 0.6619, Min 0.0000, Max 0.9569): 100%|██████████| 229/229 [00:36<00:00,  6.20it/s]
# --- EPOCH 37/100 ---
# train_batch (Avg. Loss 0.233, Min 0.019, Max 0.960), (Avg. Score 0.7674, Min 0.0405, Max 0.9812): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.470, Min 0.046, Max 1.000), (Avg. Score 0.5297, Min 0.0000, Max 0.9544): 100%|██████████| 229/229 [00:37<00:00,  6.18it/s]
# --- EPOCH 38/100 ---
# train_batch (Avg. Loss 0.225, Min 0.022, Max 1.000), (Avg. Score 0.7749, Min 0.0000, Max 0.9776): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.251, Min 0.054, Max 1.000), (Avg. Score 0.7490, Min 0.0000, Max 0.9471): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# **** Checkpoint saved ****
# --- EPOCH 39/100 ---
# train_batch (Avg. Loss 0.223, Min 0.025, Max 1.000), (Avg. Score 0.7773, Min 0.0000, Max 0.9753): 100%|██████████| 1296/1296 [09:25<00:00,  2.34it/s]
# test_batch (Avg. Loss 0.370, Min 0.041, Max 1.000), (Avg. Score 0.6298, Min 0.0000, Max 0.9583): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# --- EPOCH 40/100 ---
# train_batch (Avg. Loss 0.210, Min 0.020, Max 0.914), (Avg. Score 0.7900, Min 0.0857, Max 0.9798): 100%|██████████| 1296/1296 [09:25<00:00,  2.25it/s]
# test_batch (Avg. Loss 0.300, Min 0.035, Max 1.000), (Avg. Score 0.6998, Min 0.0000, Max 0.9646): 100%|██████████| 229/229 [00:37<00:00,  6.16it/s]
# --- EPOCH 41/100 ---
# train_batch (Avg. Loss 0.213, Min 0.018, Max 1.000), (Avg. Score 0.7876, Min 0.0000, Max 0.9821): 100%|██████████| 1296/1296 [09:25<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.268, Min 0.044, Max 1.000), (Avg. Score 0.7318, Min 0.0000, Max 0.9553): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 42/100 ---
# train_batch (Avg. Loss 0.210, Min 0.021, Max 1.000), (Avg. Score 0.7896, Min 0.0000, Max 0.9794): 100%|██████████| 1296/1296 [09:25<00:00,  2.33it/s]
# test_batch (Avg. Loss 0.419, Min 0.049, Max 1.000), (Avg. Score 0.5812, Min 0.0000, Max 0.9507): 100%|██████████| 229/229 [00:37<00:00,  6.09it/s]
# --- EPOCH 43/100 ---
# train_batch (Avg. Loss 0.209, Min 0.018, Max 0.879), (Avg. Score 0.7915, Min 0.1212, Max 0.9827): 100%|██████████| 1296/1296 [09:25<00:00,  2.27it/s]
# test_batch (Avg. Loss 0.366, Min 0.051, Max 1.000), (Avg. Score 0.6338, Min 0.0000, Max 0.9486): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# --- EPOCH 44/100 ---
# train_batch (Avg. Loss 0.193, Min 0.026, Max 0.877), (Avg. Score 0.8075, Min 0.1230, Max 0.9740): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.349, Min 0.046, Max 1.000), (Avg. Score 0.6513, Min 0.0000, Max 0.9539): 100%|██████████| 229/229 [00:37<00:00,  6.64it/s]
# --- EPOCH 45/100 ---
# train_batch (Avg. Loss 0.198, Min 0.022, Max 1.000), (Avg. Score 0.8016, Min 0.0000, Max 0.9782): 100%|██████████| 1296/1296 [09:25<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.248, Min 0.035, Max 1.000), (Avg. Score 0.7520, Min 0.0000, Max 0.9646): 100%|██████████| 229/229 [00:36<00:00,  6.19it/s]
# **** Checkpoint saved ****
# --- EPOCH 46/100 ---
# train_batch (Avg. Loss 0.197, Min 0.030, Max 0.896), (Avg. Score 0.8028, Min 0.1041, Max 0.9697): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.279, Min 0.037, Max 1.000), (Avg. Score 0.7206, Min 0.0000, Max 0.9633): 100%|██████████| 229/229 [00:37<00:00,  6.09it/s]
# --- EPOCH 47/100 ---
# train_batch (Avg. Loss 0.186, Min 0.022, Max 0.754), (Avg. Score 0.8139, Min 0.2461, Max 0.9779): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.228, Min 0.045, Max 1.000), (Avg. Score 0.7720, Min 0.0000, Max 0.9552): 100%|██████████| 229/229 [00:37<00:00,  6.08it/s]
# **** Checkpoint saved ****
# --- EPOCH 48/100 ---
# train_batch (Avg. Loss 0.184, Min 0.022, Max 0.855), (Avg. Score 0.8156, Min 0.1455, Max 0.9780): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.250, Min 0.046, Max 1.000), (Avg. Score 0.7497, Min 0.0000, Max 0.9541): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 49/100 ---
# train_batch (Avg. Loss 0.185, Min 0.017, Max 1.000), (Avg. Score 0.8147, Min 0.0000, Max 0.9829): 100%|██████████| 1296/1296 [09:25<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.270, Min 0.044, Max 1.000), (Avg. Score 0.7304, Min 0.0000, Max 0.9560): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# --- EPOCH 50/100 ---
# train_batch (Avg. Loss 0.180, Min 0.023, Max 1.000), (Avg. Score 0.8202, Min 0.0000, Max 0.9772): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.211, Min 0.045, Max 0.637), (Avg. Score 0.7890, Min 0.3621, Max 0.9550): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# **** Checkpoint saved ****
# --- EPOCH 51/100 ---
# train_batch (Avg. Loss 0.174, Min 0.018, Max 0.866), (Avg. Score 0.8264, Min 0.1343, Max 0.9826): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.259, Min 0.043, Max 1.000), (Avg. Score 0.7408, Min 0.0000, Max 0.9580): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 52/100 ---
# train_batch (Avg. Loss 0.170, Min 0.023, Max 1.000), (Avg. Score 0.8304, Min 0.0000, Max 0.9770): 100%|██████████| 1296/1296 [09:26<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.333, Min 0.042, Max 1.000), (Avg. Score 0.6674, Min 0.0000, Max 0.9583): 100%|██████████| 229/229 [00:37<00:00,  6.17it/s]
# --- EPOCH 53/100 ---
# train_batch (Avg. Loss 0.168, Min 0.022, Max 0.802), (Avg. Score 0.8318, Min 0.1978, Max 0.9785): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.270, Min 0.044, Max 0.871), (Avg. Score 0.7305, Min 0.1289, Max 0.9561): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 54/100 ---
# train_batch (Avg. Loss 0.165, Min 0.015, Max 0.788), (Avg. Score 0.8349, Min 0.2117, Max 0.9846): 100%|██████████| 1296/1296 [09:26<00:00,  2.26it/s]
# test_batch (Avg. Loss 0.228, Min 0.033, Max 0.760), (Avg. Score 0.7719, Min 0.2402, Max 0.9669): 100%|██████████| 229/229 [00:37<00:00,  6.11it/s]
# --- EPOCH 55/100 ---
# train_batch (Avg. Loss 0.160, Min 0.023, Max 0.719), (Avg. Score 0.8397, Min 0.2809, Max 0.9767): 100%|██████████| 1296/1296 [09:26<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.230, Min 0.046, Max 1.000), (Avg. Score 0.7705, Min 0.0000, Max 0.9537): 100%|██████████| 229/229 [00:37<00:00,  6.13it/s]
# --- EPOCH 56/100 ---
# train_batch (Avg. Loss 0.164, Min 0.025, Max 0.842), (Avg. Score 0.8357, Min 0.1577, Max 0.9757): 100%|██████████| 1296/1296 [09:26<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.220, Min 0.045, Max 0.759), (Avg. Score 0.7797, Min 0.2407, Max 0.9546): 100%|██████████| 229/229 [00:37<00:00,  6.11it/s]
# --- EPOCH 57/100 ---
# train_batch (Avg. Loss 0.156, Min 0.026, Max 0.973), (Avg. Score 0.8440, Min 0.0267, Max 0.9743): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.210, Min 0.034, Max 0.822), (Avg. Score 0.7898, Min 0.1801, Max 0.9663): 100%|██████████| 229/229 [00:36<00:00,  6.46it/s]
# **** Checkpoint saved ****
# --- EPOCH 58/100 ---
# train_batch (Avg. Loss 0.149, Min 0.019, Max 0.865), (Avg. Score 0.8510, Min 0.1349, Max 0.9805): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.234, Min 0.037, Max 1.000), (Avg. Score 0.7662, Min 0.0000, Max 0.9631): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# --- EPOCH 59/100 ---
# train_batch (Avg. Loss 0.151, Min 0.019, Max 0.958), (Avg. Score 0.8487, Min 0.0431, Max 0.9816): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.309, Min 0.034, Max 1.000), (Avg. Score 0.6911, Min 0.0000, Max 0.9663): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 60/100 ---
# train_batch (Avg. Loss 0.149, Min 0.021, Max 0.838), (Avg. Score 0.8507, Min 0.1617, Max 0.9792): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.251, Min 0.043, Max 1.000), (Avg. Score 0.7494, Min 0.0000, Max 0.9583): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 61/100 ---
# train_batch (Avg. Loss 0.140, Min 0.021, Max 0.849), (Avg. Score 0.8601, Min 0.1510, Max 0.9791): 100%|██████████| 1296/1296 [09:26<00:00,  2.34it/s]
# test_batch (Avg. Loss 0.194, Min 0.038, Max 0.725), (Avg. Score 0.8056, Min 0.2748, Max 0.9618): 100%|██████████| 229/229 [00:37<00:00,  6.11it/s]
# **** Checkpoint saved ****
# --- EPOCH 62/100 ---
# train_batch (Avg. Loss 0.141, Min 0.020, Max 0.749), (Avg. Score 0.8592, Min 0.2514, Max 0.9804): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.364, Min 0.040, Max 1.000), (Avg. Score 0.6358, Min 0.0000, Max 0.9604): 100%|██████████| 229/229 [00:37<00:00,  6.17it/s]
# --- EPOCH 63/100 ---
# train_batch (Avg. Loss 0.142, Min 0.018, Max 0.781), (Avg. Score 0.8578, Min 0.2185, Max 0.9818): 100%|██████████| 1296/1296 [09:26<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.252, Min 0.036, Max 1.000), (Avg. Score 0.7478, Min 0.0000, Max 0.9643): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 64/100 ---
# train_batch (Avg. Loss 0.134, Min 0.017, Max 0.660), (Avg. Score 0.8664, Min 0.3403, Max 0.9827): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.203, Min 0.041, Max 0.754), (Avg. Score 0.7975, Min 0.2457, Max 0.9591): 100%|██████████| 229/229 [00:36<00:00,  6.22it/s]
# --- EPOCH 65/100 ---
# train_batch (Avg. Loss 0.132, Min 0.023, Max 0.959), (Avg. Score 0.8680, Min 0.0410, Max 0.9766): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.262, Min 0.043, Max 1.000), (Avg. Score 0.7377, Min 0.0000, Max 0.9576): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 66/100 ---
# train_batch (Avg. Loss 0.140, Min 0.021, Max 0.911), (Avg. Score 0.8598, Min 0.0891, Max 0.9789): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.240, Min 0.035, Max 1.000), (Avg. Score 0.7602, Min 0.0000, Max 0.9657): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 67/100 ---
# train_batch (Avg. Loss 0.120, Min 0.019, Max 0.822), (Avg. Score 0.8800, Min 0.1779, Max 0.9805): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.334, Min 0.038, Max 1.000), (Avg. Score 0.6659, Min 0.0000, Max 0.9625): 100%|██████████| 229/229 [00:37<00:00,  6.15it/s]
# --- EPOCH 68/100 ---
# train_batch (Avg. Loss 0.122, Min 0.023, Max 0.693), (Avg. Score 0.8779, Min 0.3067, Max 0.9773): 100%|██████████| 1296/1296 [09:27<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.214, Min 0.033, Max 1.000), (Avg. Score 0.7863, Min 0.0000, Max 0.9670): 100%|██████████| 229/229 [00:37<00:00,  6.06it/s]
# --- EPOCH 69/100 ---
# train_batch (Avg. Loss 0.123, Min 0.018, Max 0.667), (Avg. Score 0.8775, Min 0.3325, Max 0.9815): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.191, Min 0.034, Max 0.999), (Avg. Score 0.8092, Min 0.0000, Max 0.9656): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# **** Checkpoint saved ****
# --- EPOCH 70/100 ---
# train_batch (Avg. Loss 0.124, Min 0.017, Max 1.000), (Avg. Score 0.8763, Min 0.0000, Max 0.9834): 100%|██████████| 1296/1296 [09:26<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.203, Min 0.043, Max 1.000), (Avg. Score 0.7967, Min 0.0000, Max 0.9566): 100%|██████████| 229/229 [00:37<00:00,  6.40it/s]
# --- EPOCH 71/100 ---
# train_batch (Avg. Loss 0.112, Min 0.021, Max 0.778), (Avg. Score 0.8883, Min 0.2218, Max 0.9792): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.196, Min 0.037, Max 1.000), (Avg. Score 0.8040, Min 0.0000, Max 0.9630): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 72/100 ---
# train_batch (Avg. Loss 0.110, Min 0.017, Max 0.663), (Avg. Score 0.8899, Min 0.3366, Max 0.9831): 100%|██████████| 1296/1296 [09:27<00:00,  2.27it/s]
# test_batch (Avg. Loss 0.219, Min 0.042, Max 1.000), (Avg. Score 0.7810, Min 0.0000, Max 0.9575): 100%|██████████| 229/229 [00:37<00:00,  6.18it/s]
# --- EPOCH 73/100 ---
# train_batch (Avg. Loss 0.110, Min 0.019, Max 0.659), (Avg. Score 0.8898, Min 0.3410, Max 0.9814): 100%|██████████| 1296/1296 [09:26<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.363, Min 0.036, Max 1.000), (Avg. Score 0.6375, Min 0.0000, Max 0.9637): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 74/100 ---
# train_batch (Avg. Loss 0.116, Min 0.022, Max 0.658), (Avg. Score 0.8845, Min 0.3424, Max 0.9783): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.208, Min 0.034, Max 1.000), (Avg. Score 0.7916, Min 0.0000, Max 0.9664): 100%|██████████| 229/229 [00:36<00:00,  6.23it/s]
# --- EPOCH 75/100 ---
# train_batch (Avg. Loss 0.117, Min 0.020, Max 0.624), (Avg. Score 0.8826, Min 0.3759, Max 0.9803): 100%|██████████| 1296/1296 [09:27<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.215, Min 0.037, Max 1.000), (Avg. Score 0.7852, Min 0.0000, Max 0.9629): 100%|██████████| 229/229 [00:37<00:00,  6.17it/s]
# --- EPOCH 76/100 ---
# train_batch (Avg. Loss 0.098, Min 0.023, Max 0.609), (Avg. Score 0.9016, Min 0.3918, Max 0.9768): 100%|██████████| 1296/1296 [09:26<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.205, Min 0.036, Max 1.000), (Avg. Score 0.7954, Min 0.0000, Max 0.9638): 100%|██████████| 229/229 [00:36<00:00,  6.21it/s]
# --- EPOCH 77/100 ---
# train_batch (Avg. Loss 0.110, Min 0.017, Max 0.671), (Avg. Score 0.8899, Min 0.3289, Max 0.9825): 100%|██████████| 1296/1296 [09:26<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.224, Min 0.037, Max 1.000), (Avg. Score 0.7758, Min 0.0000, Max 0.9628): 100%|██████████| 229/229 [00:37<00:00,  6.07it/s]
# --- EPOCH 78/100 ---
# train_batch (Avg. Loss 0.096, Min 0.017, Max 0.810), (Avg. Score 0.9042, Min 0.1896, Max 0.9831): 100%|██████████| 1296/1296 [09:26<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.254, Min 0.043, Max 1.000), (Avg. Score 0.7458, Min 0.0000, Max 0.9568): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 79/100 ---
# train_batch (Avg. Loss 0.098, Min 0.018, Max 0.928), (Avg. Score 0.9021, Min 0.0715, Max 0.9826): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.216, Min 0.043, Max 1.000), (Avg. Score 0.7844, Min 0.0000, Max 0.9572): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# --- EPOCH 80/100 ---
# train_batch (Avg. Loss 0.097, Min 0.022, Max 0.707), (Avg. Score 0.9035, Min 0.2886, Max 0.9783): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.202, Min 0.037, Max 1.000), (Avg. Score 0.7982, Min 0.0000, Max 0.9631): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 81/100 ---
# train_batch (Avg. Loss 0.092, Min 0.017, Max 0.634), (Avg. Score 0.9083, Min 0.3656, Max 0.9833): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.253, Min 0.039, Max 1.000), (Avg. Score 0.7469, Min 0.0000, Max 0.9609): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 82/100 ---
# train_batch (Avg. Loss 0.091, Min 0.020, Max 0.622), (Avg. Score 0.9092, Min 0.3769, Max 0.9795): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.224, Min 0.036, Max 1.000), (Avg. Score 0.7758, Min 0.0000, Max 0.9643): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# --- EPOCH 83/100 ---
# train_batch (Avg. Loss 0.088, Min 0.021, Max 0.618), (Avg. Score 0.9123, Min 0.3821, Max 0.9793): 100%|██████████| 1296/1296 [09:24<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.228, Min 0.030, Max 1.000), (Avg. Score 0.7719, Min 0.0000, Max 0.9701): 100%|██████████| 229/229 [00:37<00:00,  6.09it/s]
# --- EPOCH 84/100 ---
# train_batch (Avg. Loss 0.084, Min 0.019, Max 0.722), (Avg. Score 0.9158, Min 0.2780, Max 0.9810): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.200, Min 0.042, Max 1.000), (Avg. Score 0.8000, Min 0.0000, Max 0.9581): 100%|██████████| 229/229 [00:38<00:00,  6.02it/s]
# --- EPOCH 85/100 ---
# train_batch (Avg. Loss 0.091, Min 0.016, Max 0.627), (Avg. Score 0.9086, Min 0.3731, Max 0.9837): 100%|██████████| 1296/1296 [09:25<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.252, Min 0.035, Max 1.000), (Avg. Score 0.7478, Min 0.0000, Max 0.9651): 100%|██████████| 229/229 [00:37<00:00,  6.11it/s]
# --- EPOCH 86/100 ---
# train_batch (Avg. Loss 0.083, Min 0.014, Max 0.601), (Avg. Score 0.9168, Min 0.3991, Max 0.9861): 100%|██████████| 1296/1296 [09:25<00:00,  2.26it/s]
# test_batch (Avg. Loss 0.192, Min 0.037, Max 1.000), (Avg. Score 0.8076, Min 0.0000, Max 0.9631): 100%|██████████| 229/229 [00:37<00:00,  6.07it/s]
# --- EPOCH 87/100 ---
# train_batch (Avg. Loss 0.085, Min 0.016, Max 0.648), (Avg. Score 0.9149, Min 0.3522, Max 0.9844): 100%|██████████| 1296/1296 [09:25<00:00,  2.28it/s]
# test_batch (Avg. Loss 0.192, Min 0.030, Max 1.000), (Avg. Score 0.8084, Min 0.0000, Max 0.9704): 100%|██████████| 229/229 [00:37<00:00,  6.03it/s]
# --- EPOCH 88/100 ---
# train_batch (Avg. Loss 0.080, Min 0.017, Max 0.598), (Avg. Score 0.9198, Min 0.4019, Max 0.9834): 100%|██████████| 1296/1296 [09:24<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.210, Min 0.041, Max 1.000), (Avg. Score 0.7905, Min 0.0000, Max 0.9588): 100%|██████████| 229/229 [00:38<00:00,  5.96it/s]
# --- EPOCH 89/100 ---
# train_batch (Avg. Loss 0.077, Min 0.019, Max 0.592), (Avg. Score 0.9233, Min 0.4078, Max 0.9807): 100%|██████████| 1296/1296 [09:25<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.228, Min 0.037, Max 1.000), (Avg. Score 0.7720, Min 0.0000, Max 0.9626): 100%|██████████| 229/229 [00:37<00:00,  6.05it/s]
# --- EPOCH 90/100 ---
# train_batch (Avg. Loss 0.077, Min 0.018, Max 0.612), (Avg. Score 0.9229, Min 0.3865, Max 0.9823): 100%|██████████| 1296/1296 [09:25<00:00,  2.27it/s]
# test_batch (Avg. Loss 0.214, Min 0.037, Max 1.000), (Avg. Score 0.7861, Min 0.0000, Max 0.9629): 100%|██████████| 229/229 [00:37<00:00,  7.03it/s]
# --- EPOCH 91/100 ---
# train_batch (Avg. Loss 0.076, Min 0.020, Max 0.634), (Avg. Score 0.9236, Min 0.3657, Max 0.9802): 100%|██████████| 1296/1296 [09:25<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.194, Min 0.038, Max 1.000), (Avg. Score 0.8057, Min 0.0000, Max 0.9618): 100%|██████████| 229/229 [00:37<00:00,  6.14it/s]
# --- EPOCH 92/100 ---
# train_batch (Avg. Loss 0.086, Min 0.021, Max 0.580), (Avg. Score 0.9143, Min 0.4192, Max 0.9794): 100%|██████████| 1296/1296 [09:25<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.221, Min 0.036, Max 0.878), (Avg. Score 0.7786, Min 0.1218, Max 0.9646): 100%|██████████| 229/229 [00:37<00:00,  6.10it/s]
# --- EPOCH 93/100 ---
# train_batch (Avg. Loss 0.077, Min 0.016, Max 0.564), (Avg. Score 0.9231, Min 0.4363, Max 0.9844): 100%|██████████| 1296/1296 [09:25<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.221, Min 0.038, Max 0.930), (Avg. Score 0.7793, Min 0.0696, Max 0.9623): 100%|██████████| 229/229 [00:37<00:00,  6.07it/s]
# --- EPOCH 94/100 ---
# train_batch (Avg. Loss 0.077, Min 0.015, Max 0.614), (Avg. Score 0.9227, Min 0.3863, Max 0.9853): 100%|██████████| 1296/1296 [09:25<00:00,  2.30it/s]
# test_batch (Avg. Loss 0.218, Min 0.042, Max 1.000), (Avg. Score 0.7820, Min 0.0000, Max 0.9580): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 95/100 ---
# train_batch (Avg. Loss 0.079, Min 0.017, Max 0.678), (Avg. Score 0.9209, Min 0.3218, Max 0.9828): 100%|██████████| 1296/1296 [09:27<00:00,  2.27it/s]
# test_batch (Avg. Loss 0.190, Min 0.039, Max 1.000), (Avg. Score 0.8098, Min 0.0000, Max 0.9604): 100%|██████████| 229/229 [00:37<00:00,  6.05it/s]
# **** Checkpoint saved ****
# --- EPOCH 96/100 ---
# train_batch (Avg. Loss 0.067, Min 0.020, Max 0.546), (Avg. Score 0.9330, Min 0.4542, Max 0.9798): 100%|██████████| 1296/1296 [09:27<00:00,  2.31it/s]
# test_batch (Avg. Loss 0.194, Min 0.036, Max 0.889), (Avg. Score 0.8064, Min 0.1096, Max 0.9639): 100%|██████████| 229/229 [00:38<00:00,  5.98it/s]
# --- EPOCH 97/100 ---
# train_batch (Avg. Loss 0.070, Min 0.018, Max 0.549), (Avg. Score 0.9300, Min 0.4513, Max 0.9817): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.205, Min 0.044, Max 1.000), (Avg. Score 0.7946, Min 0.0000, Max 0.9562): 100%|██████████| 229/229 [00:37<00:00,  6.09it/s]
# --- EPOCH 98/100 ---
# train_batch (Avg. Loss 0.066, Min 0.019, Max 0.543), (Avg. Score 0.9341, Min 0.4568, Max 0.9805): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.254, Min 0.032, Max 1.000), (Avg. Score 0.7459, Min 0.0000, Max 0.9677): 100%|██████████| 229/229 [00:37<00:00,  6.12it/s]
# --- EPOCH 99/100 ---
# train_batch (Avg. Loss 0.068, Min 0.021, Max 0.567), (Avg. Score 0.9317, Min 0.4335, Max 0.9792): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.195, Min 0.042, Max 1.000), (Avg. Score 0.8050, Min 0.0000, Max 0.9580): 100%|██████████| 229/229 [00:37<00:00,  6.04it/s]
# --- EPOCH 100/100 ---
# train_batch (Avg. Loss 0.072, Min 0.017, Max 0.608), (Avg. Score 0.9279, Min 0.3919, Max 0.9834): 100%|██████████| 1296/1296 [09:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.228, Min 0.036, Max 1.000), (Avg. Score 0.7721, Min 0.0000, Max 0.9638): 100%|██████████| 229/229 [00:37<00:00,  6.45it/s]

# %%
from cs236605.plot import plot_fit
plot_fit(fit_res)
# Out:
# (<Figure size 1152x720 with 4 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe3ac922dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe3ac90e650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe3ac8c0310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe3ac87d4d0>],
#        dtype=object))

# %%
print(fit_res.best_score)
# Out:
# tensor(0.8098, device='cuda:0')
