# %% [markdown]
# # Experiment HybridResUnet
# #### Setup:
# **Dataset**: 3 different types of brain tumors <br>
# **Loss function**: Dice loss <br>
# **Optimizer**: Adam <br>
# **Model**: Hybrid solution of Res blocks in the  down path and double conv layers in up path

# %%
# Imports and training parameters
import torch
from torchvision.transforms import transforms
from src.datasets import BrainTumorDatasetMask
from src.loss import  dice_loss
from src.metrics import dice_coeff
from src.models import  ResUNet
from src.trainers import Trainer
torch.manual_seed(0)
num_epochs = 100
batch_size = 2
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Data preparation
# load the data see data_preprocessing notebook for more explanation

def normalize(x,  mean=470, std=None):
    mean_tansor = torch.ones_like(x) * mean
    x -= mean_tansor
    if std:
        x /= std
    return x

def preprocessing(image, mask):
    mask_transformer = transforms.Compose([
        transforms.ToTensor()    
    ])

    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: normalize(x))
    ])
    return image_transformer(image).float(), mask_transformer(mask).float()

target_folder = './data/'
ds_train = BrainTumorDatasetMask(root=target_folder, train=True, transform=preprocessing)
ds_test = BrainTumorDatasetMask(root=target_folder, train=False, transform=preprocessing)
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=True)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size, shuffle=False)
# Out:
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script

# %%
# Training and evaluation
model = ResUNet()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = dice_loss
success_metric = dice_coeff
trainer = Trainer(model, criterion, optimizer, dice_coeff, device, None)
fit_res = trainer.fit(dl_train, 
                      dl_test,
                      num_epochs= num_epochs,
                      checkpoints='src/saved_models/' + model.__class__.__name__)
# Out:
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 0.870, Min 0.463, Max 1.000), (Avg. Score 0.1326, Min 0.0000, Max 0.5660): 100%|██████████| 1296/1296 [09:45<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.990, Min 0.325, Max 1.000), (Avg. Score 0.0095, Min 0.0000, Max 0.7063): 100%|██████████| 229/229 [00:38<00:00,  6.03it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 0.790, Min 0.209, Max 1.000), (Avg. Score 0.2106, Min 0.0000, Max 0.7920): 100%|██████████| 1296/1296 [09:46<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.884, Min 0.298, Max 1.000), (Avg. Score 0.1161, Min 0.0000, Max 0.7039): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# **** Checkpoint saved ****
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 0.688, Min 0.086, Max 1.000), (Avg. Score 0.3130, Min 0.0000, Max 0.9157): 100%|██████████| 1296/1296 [09:48<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.710, Min 0.150, Max 1.000), (Avg. Score 0.2908, Min 0.0000, Max 0.8527): 100%|██████████| 229/229 [00:38<00:00,  5.95it/s]
# **** Checkpoint saved ****
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 0.590, Min 0.077, Max 1.000), (Avg. Score 0.4107, Min 0.0000, Max 0.9238): 100%|██████████| 1296/1296 [09:48<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.665, Min 0.105, Max 1.000), (Avg. Score 0.3348, Min 0.0000, Max 0.8962): 100%|██████████| 229/229 [00:38<00:00,  6.51it/s]
# **** Checkpoint saved ****
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 0.539, Min 0.054, Max 1.000), (Avg. Score 0.4619, Min 0.0000, Max 0.9465): 100%|██████████| 1296/1296 [09:47<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.581, Min 0.074, Max 1.000), (Avg. Score 0.4190, Min 0.0000, Max 0.9255): 100%|██████████| 229/229 [00:38<00:00,  6.01it/s]
# **** Checkpoint saved ****
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 0.483, Min 0.058, Max 1.000), (Avg. Score 0.5174, Min 0.0000, Max 0.9422): 100%|██████████| 1296/1296 [09:48<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.713, Min 0.115, Max 1.000), (Avg. Score 0.2868, Min 0.0000, Max 0.8848): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 0.444, Min 0.060, Max 1.000), (Avg. Score 0.5567, Min 0.0000, Max 0.9404): 100%|██████████| 1296/1296 [09:48<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.674, Min 0.085, Max 1.000), (Avg. Score 0.3258, Min 0.0000, Max 0.9158): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 0.413, Min 0.038, Max 1.000), (Avg. Score 0.5876, Min 0.0000, Max 0.9628): 100%|██████████| 1296/1296 [09:48<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.582, Min 0.056, Max 1.000), (Avg. Score 0.4181, Min 0.0000, Max 0.9444): 100%|██████████| 229/229 [00:38<00:00,  5.96it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 0.388, Min 0.035, Max 0.999), (Avg. Score 0.6124, Min 0.0006, Max 0.9648): 100%|██████████| 1296/1296 [09:48<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.495, Min 0.048, Max 1.000), (Avg. Score 0.5052, Min 0.0000, Max 0.9526): 100%|██████████| 229/229 [00:38<00:00,  6.00it/s]
# **** Checkpoint saved ****
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 0.359, Min 0.042, Max 1.000), (Avg. Score 0.6409, Min 0.0000, Max 0.9588): 100%|██████████| 1296/1296 [09:48<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.609, Min 0.052, Max 1.000), (Avg. Score 0.3916, Min 0.0000, Max 0.9478): 100%|██████████| 229/229 [00:39<00:00,  6.57it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.348, Min 0.033, Max 1.000), (Avg. Score 0.6524, Min 0.0000, Max 0.9671): 100%|██████████| 1296/1296 [09:48<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.478, Min 0.061, Max 1.000), (Avg. Score 0.5231, Min 0.0000, Max 0.9402): 100%|██████████| 229/229 [00:38<00:00,  5.93it/s]
# **** Checkpoint saved ****
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 0.329, Min 0.033, Max 1.000), (Avg. Score 0.6717, Min 0.0000, Max 0.9674): 100%|██████████| 1296/1296 [09:48<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.454, Min 0.052, Max 1.000), (Avg. Score 0.5461, Min 0.0000, Max 0.9488): 100%|██████████| 229/229 [00:38<00:00,  5.98it/s]
# **** Checkpoint saved ****
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 0.316, Min 0.031, Max 1.000), (Avg. Score 0.6837, Min 0.0000, Max 0.9689): 100%|██████████| 1296/1296 [09:48<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.447, Min 0.054, Max 1.000), (Avg. Score 0.5535, Min 0.0000, Max 0.9467): 100%|██████████| 229/229 [00:38<00:00,  5.89it/s]
# **** Checkpoint saved ****
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.307, Min 0.020, Max 1.000), (Avg. Score 0.6931, Min 0.0000, Max 0.9802): 100%|██████████| 1296/1296 [09:49<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.363, Min 0.061, Max 1.000), (Avg. Score 0.6371, Min 0.0000, Max 0.9391): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# **** Checkpoint saved ****
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.290, Min 0.025, Max 0.928), (Avg. Score 0.7104, Min 0.0718, Max 0.9752): 100%|██████████| 1296/1296 [09:48<00:00,  2.24it/s]
# test_batch (Avg. Loss 0.456, Min 0.038, Max 1.000), (Avg. Score 0.5439, Min 0.0000, Max 0.9628): 100%|██████████| 229/229 [00:38<00:00,  5.98it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.276, Min 0.030, Max 0.873), (Avg. Score 0.7239, Min 0.1268, Max 0.9703): 100%|██████████| 1296/1296 [09:48<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.401, Min 0.060, Max 1.000), (Avg. Score 0.5995, Min 0.0000, Max 0.9399): 100%|██████████| 229/229 [00:38<00:00,  5.89it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.267, Min 0.022, Max 1.000), (Avg. Score 0.7333, Min 0.0000, Max 0.9781): 100%|██████████| 1296/1296 [09:49<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.331, Min 0.039, Max 1.000), (Avg. Score 0.6696, Min 0.0000, Max 0.9606): 100%|██████████| 229/229 [00:38<00:00,  5.98it/s]
# **** Checkpoint saved ****
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.255, Min 0.029, Max 1.000), (Avg. Score 0.7452, Min 0.0000, Max 0.9713): 100%|██████████| 1296/1296 [09:49<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.259, Min 0.051, Max 0.957), (Avg. Score 0.7407, Min 0.0314, Max 0.9493): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# **** Checkpoint saved ****
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.247, Min 0.031, Max 0.998), (Avg. Score 0.7534, Min 0.0023, Max 0.9693): 100%|██████████| 1296/1296 [09:48<00:00,  2.23it/s]
# test_batch (Avg. Loss 0.292, Min 0.049, Max 1.000), (Avg. Score 0.7080, Min 0.0000, Max 0.9509): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.243, Min 0.026, Max 1.000), (Avg. Score 0.7575, Min 0.0000, Max 0.9738): 100%|██████████| 1296/1296 [09:48<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.289, Min 0.042, Max 1.000), (Avg. Score 0.7112, Min 0.0000, Max 0.9585): 100%|██████████| 229/229 [00:38<00:00,  5.89it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.236, Min 0.022, Max 0.832), (Avg. Score 0.7641, Min 0.1667, Max 0.9774): 100%|██████████| 1296/1296 [09:48<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.239, Min 0.046, Max 0.910), (Avg. Score 0.7615, Min 0.0887, Max 0.9538): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# **** Checkpoint saved ****
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.220, Min 0.026, Max 1.000), (Avg. Score 0.7797, Min 0.0000, Max 0.9740): 100%|██████████| 1296/1296 [09:48<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.277, Min 0.044, Max 0.834), (Avg. Score 0.7232, Min 0.1628, Max 0.9553): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.212, Min 0.025, Max 0.996), (Avg. Score 0.7884, Min 0.0044, Max 0.9750): 100%|██████████| 1296/1296 [09:49<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.273, Min 0.055, Max 1.000), (Avg. Score 0.7272, Min 0.0000, Max 0.9451): 100%|██████████| 229/229 [00:39<00:00,  5.87it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.205, Min 0.022, Max 0.953), (Avg. Score 0.7956, Min 0.0467, Max 0.9781): 100%|██████████| 1296/1296 [09:49<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.235, Min 0.037, Max 0.905), (Avg. Score 0.7656, Min 0.0942, Max 0.9632): 100%|██████████| 229/229 [00:38<00:00,  5.94it/s]
# **** Checkpoint saved ****
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.198, Min 0.028, Max 1.000), (Avg. Score 0.8019, Min 0.0000, Max 0.9718): 100%|██████████| 1296/1296 [09:49<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.277, Min 0.052, Max 0.802), (Avg. Score 0.7228, Min 0.1958, Max 0.9482): 100%|██████████| 229/229 [00:38<00:00,  5.91it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.189, Min 0.026, Max 0.896), (Avg. Score 0.8113, Min 0.1030, Max 0.9747): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.257, Min 0.041, Max 1.000), (Avg. Score 0.7435, Min 0.0000, Max 0.9590): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.189, Min 0.028, Max 0.872), (Avg. Score 0.8110, Min 0.1277, Max 0.9724): 100%|██████████| 1296/1296 [09:49<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.219, Min 0.041, Max 0.699), (Avg. Score 0.7816, Min 0.3008, Max 0.9586): 100%|██████████| 229/229 [00:38<00:00,  5.93it/s]
# **** Checkpoint saved ****
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.176, Min 0.025, Max 0.837), (Avg. Score 0.8243, Min 0.1632, Max 0.9748): 100%|██████████| 1296/1296 [09:49<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.396, Min 0.040, Max 1.000), (Avg. Score 0.6041, Min 0.0000, Max 0.9605): 100%|██████████| 229/229 [00:38<00:00,  5.96it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.179, Min 0.017, Max 0.770), (Avg. Score 0.8209, Min 0.2304, Max 0.9835): 100%|██████████| 1296/1296 [09:49<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.261, Min 0.048, Max 1.000), (Avg. Score 0.7389, Min 0.0000, Max 0.9528): 100%|██████████| 229/229 [00:38<00:00,  5.96it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.169, Min 0.023, Max 0.904), (Avg. Score 0.8312, Min 0.0954, Max 0.9768): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.252, Min 0.051, Max 0.816), (Avg. Score 0.7484, Min 0.1835, Max 0.9497): 100%|██████████| 229/229 [00:38<00:00,  5.94it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.167, Min 0.025, Max 0.835), (Avg. Score 0.8332, Min 0.1652, Max 0.9750): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.216, Min 0.038, Max 0.758), (Avg. Score 0.7842, Min 0.2422, Max 0.9627): 100%|██████████| 229/229 [00:38<00:00,  6.56it/s]
# **** Checkpoint saved ****
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.147, Min 0.026, Max 0.660), (Avg. Score 0.8528, Min 0.3399, Max 0.9743): 100%|██████████| 1296/1296 [09:49<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.214, Min 0.038, Max 1.000), (Avg. Score 0.7862, Min 0.0000, Max 0.9616): 100%|██████████| 229/229 [00:39<00:00,  5.85it/s]
# **** Checkpoint saved ****
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.148, Min 0.027, Max 0.857), (Avg. Score 0.8523, Min 0.1425, Max 0.9735): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.246, Min 0.041, Max 1.000), (Avg. Score 0.7542, Min 0.0000, Max 0.9591): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.144, Min 0.020, Max 1.000), (Avg. Score 0.8558, Min 0.0000, Max 0.9799): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.228, Min 0.034, Max 1.000), (Avg. Score 0.7717, Min 0.0000, Max 0.9658): 100%|██████████| 229/229 [00:39<00:00,  5.87it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.149, Min 0.024, Max 0.886), (Avg. Score 0.8512, Min 0.1138, Max 0.9765): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.226, Min 0.042, Max 0.626), (Avg. Score 0.7737, Min 0.3728, Max 0.9577): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.134, Min 0.026, Max 0.748), (Avg. Score 0.8664, Min 0.2525, Max 0.9737): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.304, Min 0.037, Max 1.000), (Avg. Score 0.6957, Min 0.0000, Max 0.9634): 100%|██████████| 229/229 [00:39<00:00,  5.87it/s]
# --- EPOCH 37/100 ---
# train_batch (Avg. Loss 0.131, Min 0.025, Max 0.751), (Avg. Score 0.8696, Min 0.2492, Max 0.9754): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.223, Min 0.046, Max 1.000), (Avg. Score 0.7774, Min 0.0000, Max 0.9539): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 38/100 ---
# train_batch (Avg. Loss 0.125, Min 0.021, Max 0.732), (Avg. Score 0.8755, Min 0.2681, Max 0.9786): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.181, Min 0.035, Max 1.000), (Avg. Score 0.8186, Min 0.0000, Max 0.9654): 100%|██████████| 229/229 [00:39<00:00,  5.81it/s]
# **** Checkpoint saved ****
# --- EPOCH 39/100 ---
# train_batch (Avg. Loss 0.118, Min 0.022, Max 0.731), (Avg. Score 0.8824, Min 0.2693, Max 0.9775): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.187, Min 0.044, Max 1.000), (Avg. Score 0.8134, Min 0.0000, Max 0.9562): 100%|██████████| 229/229 [00:38<00:00,  6.62it/s]
# --- EPOCH 40/100 ---
# train_batch (Avg. Loss 0.116, Min 0.023, Max 0.652), (Avg. Score 0.8842, Min 0.3484, Max 0.9766): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.184, Min 0.028, Max 1.000), (Avg. Score 0.8162, Min 0.0000, Max 0.9717): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 41/100 ---
# train_batch (Avg. Loss 0.121, Min 0.022, Max 0.872), (Avg. Score 0.8791, Min 0.1278, Max 0.9781): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.187, Min 0.032, Max 1.000), (Avg. Score 0.8126, Min 0.0000, Max 0.9681): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 42/100 ---
# train_batch (Avg. Loss 0.111, Min 0.021, Max 0.629), (Avg. Score 0.8895, Min 0.3710, Max 0.9793): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.198, Min 0.035, Max 1.000), (Avg. Score 0.8017, Min 0.0000, Max 0.9647): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# --- EPOCH 43/100 ---
# train_batch (Avg. Loss 0.106, Min 0.017, Max 0.639), (Avg. Score 0.8944, Min 0.3589, Max 0.9829): 100%|██████████| 1296/1296 [09:51<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.197, Min 0.039, Max 1.000), (Avg. Score 0.8033, Min 0.0000, Max 0.9613): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# --- EPOCH 44/100 ---
# train_batch (Avg. Loss 0.109, Min 0.022, Max 0.734), (Avg. Score 0.8915, Min 0.2663, Max 0.9781): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.205, Min 0.038, Max 1.000), (Avg. Score 0.7951, Min 0.0000, Max 0.9620): 100%|██████████| 229/229 [00:38<00:00,  5.94it/s]
# --- EPOCH 45/100 ---
# train_batch (Avg. Loss 0.100, Min 0.022, Max 0.669), (Avg. Score 0.9005, Min 0.3312, Max 0.9783): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.180, Min 0.037, Max 0.745), (Avg. Score 0.8196, Min 0.2549, Max 0.9627): 100%|██████████| 229/229 [00:38<00:00,  5.91it/s]
# **** Checkpoint saved ****
# --- EPOCH 46/100 ---
# train_batch (Avg. Loss 0.102, Min 0.023, Max 0.730), (Avg. Score 0.8985, Min 0.2696, Max 0.9766): 100%|██████████| 1296/1296 [09:51<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.192, Min 0.036, Max 0.987), (Avg. Score 0.8081, Min 0.0052, Max 0.9643): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 47/100 ---
# train_batch (Avg. Loss 0.093, Min 0.022, Max 0.816), (Avg. Score 0.9071, Min 0.1845, Max 0.9784): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.191, Min 0.036, Max 0.794), (Avg. Score 0.8091, Min 0.2005, Max 0.9646): 100%|██████████| 229/229 [00:38<00:00,  5.92it/s]
# --- EPOCH 48/100 ---
# train_batch (Avg. Loss 0.091, Min 0.018, Max 1.000), (Avg. Score 0.9092, Min 0.0000, Max 0.9825): 100%|██████████| 1296/1296 [09:51<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.187, Min 0.037, Max 1.000), (Avg. Score 0.8129, Min 0.0000, Max 0.9628): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 49/100 ---
# train_batch (Avg. Loss 0.091, Min 0.023, Max 0.560), (Avg. Score 0.9086, Min 0.4397, Max 0.9771): 100%|██████████| 1296/1296 [09:51<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.163, Min 0.034, Max 0.706), (Avg. Score 0.8366, Min 0.2998, Max 0.9658): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# **** Checkpoint saved ****
# --- EPOCH 50/100 ---
# train_batch (Avg. Loss 0.084, Min 0.019, Max 0.568), (Avg. Score 0.9160, Min 0.4323, Max 0.9815): 100%|██████████| 1296/1296 [09:51<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.182, Min 0.042, Max 0.992), (Avg. Score 0.8180, Min 0.0026, Max 0.9575): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 51/100 ---
# train_batch (Avg. Loss 0.084, Min 0.021, Max 0.610), (Avg. Score 0.9157, Min 0.3899, Max 0.9789): 100%|██████████| 1296/1296 [09:51<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.193, Min 0.037, Max 1.000), (Avg. Score 0.8069, Min 0.0000, Max 0.9633): 100%|██████████| 229/229 [00:39<00:00,  6.48it/s]
# --- EPOCH 52/100 ---
# train_batch (Avg. Loss 0.088, Min 0.017, Max 0.704), (Avg. Score 0.9116, Min 0.2944, Max 0.9828): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.214, Min 0.032, Max 0.916), (Avg. Score 0.7865, Min 0.0881, Max 0.9675): 100%|██████████| 229/229 [00:39<00:00,  6.68it/s]
# --- EPOCH 53/100 ---
# train_batch (Avg. Loss 0.079, Min 0.021, Max 0.618), (Avg. Score 0.9208, Min 0.3819, Max 0.9785): 100%|██████████| 1296/1296 [09:51<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.211, Min 0.038, Max 0.954), (Avg. Score 0.7885, Min 0.0401, Max 0.9618): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 54/100 ---
# train_batch (Avg. Loss 0.074, Min 0.019, Max 0.590), (Avg. Score 0.9256, Min 0.4104, Max 0.9815): 100%|██████████| 1296/1296 [09:51<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.178, Min 0.039, Max 0.685), (Avg. Score 0.8216, Min 0.3136, Max 0.9607): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 55/100 ---
# train_batch (Avg. Loss 0.079, Min 0.018, Max 0.736), (Avg. Score 0.9213, Min 0.2638, Max 0.9815): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.193, Min 0.038, Max 1.000), (Avg. Score 0.8070, Min 0.0000, Max 0.9623): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# --- EPOCH 56/100 ---
# train_batch (Avg. Loss 0.075, Min 0.016, Max 0.561), (Avg. Score 0.9248, Min 0.4388, Max 0.9847): 100%|██████████| 1296/1296 [09:51<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.177, Min 0.041, Max 0.707), (Avg. Score 0.8235, Min 0.2919, Max 0.9591): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# --- EPOCH 57/100 ---
# train_batch (Avg. Loss 0.071, Min 0.020, Max 0.594), (Avg. Score 0.9287, Min 0.4094, Max 0.9805): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.231, Min 0.043, Max 0.951), (Avg. Score 0.7690, Min 0.0479, Max 0.9570): 100%|██████████| 229/229 [00:39<00:00,  5.73it/s]
# --- EPOCH 58/100 ---
# train_batch (Avg. Loss 0.071, Min 0.019, Max 0.770), (Avg. Score 0.9292, Min 0.2303, Max 0.9813): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.210, Min 0.040, Max 0.956), (Avg. Score 0.7899, Min 0.0449, Max 0.9600): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 59/100 ---
# train_batch (Avg. Loss 0.068, Min 0.019, Max 0.583), (Avg. Score 0.9325, Min 0.4169, Max 0.9814): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.196, Min 0.038, Max 0.959), (Avg. Score 0.8046, Min 0.0425, Max 0.9618): 100%|██████████| 229/229 [00:39<00:00,  5.78it/s]
# --- EPOCH 60/100 ---
# train_batch (Avg. Loss 0.065, Min 0.018, Max 0.558), (Avg. Score 0.9346, Min 0.4416, Max 0.9822): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.187, Min 0.042, Max 0.643), (Avg. Score 0.8134, Min 0.3554, Max 0.9584): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 61/100 ---
# train_batch (Avg. Loss 0.067, Min 0.017, Max 0.552), (Avg. Score 0.9328, Min 0.4484, Max 0.9827): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.185, Min 0.037, Max 0.757), (Avg. Score 0.8150, Min 0.2428, Max 0.9629): 100%|██████████| 229/229 [00:39<00:00,  5.78it/s]
# --- EPOCH 62/100 ---
# train_batch (Avg. Loss 0.070, Min 0.021, Max 0.879), (Avg. Score 0.9301, Min 0.1220, Max 0.9795): 100%|██████████| 1296/1296 [09:49<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.187, Min 0.039, Max 0.713), (Avg. Score 0.8136, Min 0.2874, Max 0.9609): 100%|██████████| 229/229 [00:39<00:00,  6.55it/s]
# --- EPOCH 63/100 ---
# train_batch (Avg. Loss 0.063, Min 0.018, Max 0.546), (Avg. Score 0.9368, Min 0.4537, Max 0.9824): 100%|██████████| 1296/1296 [09:49<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.200, Min 0.041, Max 0.811), (Avg. Score 0.8001, Min 0.1903, Max 0.9595): 100%|██████████| 229/229 [00:40<00:00,  5.71it/s]
# --- EPOCH 64/100 ---
# train_batch (Avg. Loss 0.060, Min 0.018, Max 0.645), (Avg. Score 0.9402, Min 0.3544, Max 0.9815): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.169, Min 0.031, Max 0.740), (Avg. Score 0.8314, Min 0.2606, Max 0.9690): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 65/100 ---
# train_batch (Avg. Loss 0.058, Min 0.017, Max 0.549), (Avg. Score 0.9418, Min 0.4512, Max 0.9828): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.180, Min 0.038, Max 1.000), (Avg. Score 0.8197, Min 0.0000, Max 0.9616): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 66/100 ---
# train_batch (Avg. Loss 0.064, Min 0.018, Max 0.556), (Avg. Score 0.9359, Min 0.4442, Max 0.9819): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.183, Min 0.039, Max 0.662), (Avg. Score 0.8170, Min 0.3374, Max 0.9613): 100%|██████████| 229/229 [00:39<00:00,  6.66it/s]
# --- EPOCH 67/100 ---
# train_batch (Avg. Loss 0.067, Min 0.018, Max 0.546), (Avg. Score 0.9328, Min 0.4546, Max 0.9819): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.234, Min 0.036, Max 1.000), (Avg. Score 0.7659, Min 0.0000, Max 0.9641): 100%|██████████| 229/229 [00:40<00:00,  5.70it/s]
# --- EPOCH 68/100 ---
# train_batch (Avg. Loss 0.059, Min 0.014, Max 0.611), (Avg. Score 0.9413, Min 0.3891, Max 0.9857): 100%|██████████| 1296/1296 [09:49<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.176, Min 0.040, Max 0.667), (Avg. Score 0.8246, Min 0.3323, Max 0.9596): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 69/100 ---
# train_batch (Avg. Loss 0.054, Min 0.019, Max 0.548), (Avg. Score 0.9464, Min 0.4522, Max 0.9816): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.185, Min 0.039, Max 0.989), (Avg. Score 0.8153, Min 0.0103, Max 0.9612): 100%|██████████| 229/229 [00:39<00:00,  6.53it/s]
# --- EPOCH 70/100 ---
# train_batch (Avg. Loss 0.054, Min 0.017, Max 0.566), (Avg. Score 0.9462, Min 0.4338, Max 0.9831): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.181, Min 0.043, Max 0.948), (Avg. Score 0.8186, Min 0.0496, Max 0.9571): 100%|██████████| 229/229 [00:39<00:00,  6.08it/s]
# --- EPOCH 71/100 ---
# train_batch (Avg. Loss 0.053, Min 0.016, Max 0.590), (Avg. Score 0.9471, Min 0.4095, Max 0.9841): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.204, Min 0.041, Max 1.000), (Avg. Score 0.7955, Min 0.0000, Max 0.9587): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 72/100 ---
# train_batch (Avg. Loss 0.056, Min 0.016, Max 0.550), (Avg. Score 0.9442, Min 0.4501, Max 0.9838): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.171, Min 0.034, Max 0.911), (Avg. Score 0.8288, Min 0.0924, Max 0.9662): 100%|██████████| 229/229 [00:39<00:00,  5.78it/s]
# --- EPOCH 73/100 ---
# train_batch (Avg. Loss 0.055, Min 0.016, Max 0.559), (Avg. Score 0.9453, Min 0.4412, Max 0.9840): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.204, Min 0.042, Max 1.000), (Avg. Score 0.7956, Min 0.0000, Max 0.9583): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 74/100 ---
# train_batch (Avg. Loss 0.051, Min 0.013, Max 0.532), (Avg. Score 0.9494, Min 0.4677, Max 0.9866): 100%|██████████| 1296/1296 [09:51<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.188, Min 0.043, Max 0.917), (Avg. Score 0.8124, Min 0.0858, Max 0.9571): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 75/100 ---
# train_batch (Avg. Loss 0.049, Min 0.017, Max 0.572), (Avg. Score 0.9509, Min 0.4281, Max 0.9834): 100%|██████████| 1296/1296 [09:50<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.197, Min 0.036, Max 1.000), (Avg. Score 0.8034, Min 0.0000, Max 0.9639): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 76/100 ---
# train_batch (Avg. Loss 0.053, Min 0.015, Max 0.931), (Avg. Score 0.9469, Min 0.0710, Max 0.9845): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.185, Min 0.045, Max 1.000), (Avg. Score 0.8149, Min 0.0000, Max 0.9555): 100%|██████████| 229/229 [00:39<00:00,  6.27it/s]
# --- EPOCH 77/100 ---
# train_batch (Avg. Loss 0.049, Min 0.017, Max 0.559), (Avg. Score 0.9511, Min 0.4411, Max 0.9832): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.216, Min 0.037, Max 1.000), (Avg. Score 0.7840, Min 0.0000, Max 0.9629): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# --- EPOCH 78/100 ---
# train_batch (Avg. Loss 0.051, Min 0.016, Max 0.603), (Avg. Score 0.9493, Min 0.3969, Max 0.9842): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.177, Min 0.029, Max 0.992), (Avg. Score 0.8234, Min 0.0078, Max 0.9714): 100%|██████████| 229/229 [00:39<00:00,  5.80it/s]
# --- EPOCH 79/100 ---
# train_batch (Avg. Loss 0.048, Min 0.016, Max 0.590), (Avg. Score 0.9516, Min 0.4102, Max 0.9844): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.188, Min 0.039, Max 0.992), (Avg. Score 0.8123, Min 0.0078, Max 0.9605): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 80/100 ---
# train_batch (Avg. Loss 0.046, Min 0.014, Max 0.540), (Avg. Score 0.9543, Min 0.4602, Max 0.9863): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.187, Min 0.037, Max 1.000), (Avg. Score 0.8127, Min 0.0000, Max 0.9627): 100%|██████████| 229/229 [00:40<00:00,  5.69it/s]
# --- EPOCH 81/100 ---
# train_batch (Avg. Loss 0.049, Min 0.015, Max 0.831), (Avg. Score 0.9508, Min 0.1692, Max 0.9851): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.167, Min 0.028, Max 0.608), (Avg. Score 0.8329, Min 0.3915, Max 0.9722): 100%|██████████| 229/229 [00:39<00:00,  6.61it/s]
# --- EPOCH 82/100 ---
# train_batch (Avg. Loss 0.046, Min 0.015, Max 0.534), (Avg. Score 0.9537, Min 0.4664, Max 0.9852): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.195, Min 0.038, Max 1.000), (Avg. Score 0.8053, Min 0.0000, Max 0.9624): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 83/100 ---
# train_batch (Avg. Loss 0.044, Min 0.014, Max 0.596), (Avg. Score 0.9561, Min 0.4041, Max 0.9864): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.181, Min 0.036, Max 1.000), (Avg. Score 0.8187, Min 0.0000, Max 0.9636): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 84/100 ---
# train_batch (Avg. Loss 0.043, Min 0.015, Max 0.585), (Avg. Score 0.9566, Min 0.4155, Max 0.9854): 100%|██████████| 1296/1296 [09:50<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.197, Min 0.033, Max 1.000), (Avg. Score 0.8030, Min 0.0000, Max 0.9673): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 85/100 ---
# train_batch (Avg. Loss 0.044, Min 0.015, Max 0.550), (Avg. Score 0.9559, Min 0.4505, Max 0.9848): 100%|██████████| 1296/1296 [09:49<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.194, Min 0.033, Max 1.000), (Avg. Score 0.8055, Min 0.0000, Max 0.9671): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 86/100 ---
# train_batch (Avg. Loss 0.045, Min 0.015, Max 0.534), (Avg. Score 0.9551, Min 0.4664, Max 0.9851): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.213, Min 0.039, Max 1.000), (Avg. Score 0.7865, Min 0.0000, Max 0.9612): 100%|██████████| 229/229 [00:39<00:00,  5.87it/s]
# --- EPOCH 87/100 ---
# train_batch (Avg. Loss 0.048, Min 0.014, Max 0.566), (Avg. Score 0.9524, Min 0.4345, Max 0.9859): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.178, Min 0.037, Max 0.967), (Avg. Score 0.8219, Min 0.0299, Max 0.9630): 100%|██████████| 229/229 [00:40<00:00,  6.53it/s]
# --- EPOCH 88/100 ---
# train_batch (Avg. Loss 0.043, Min 0.015, Max 0.523), (Avg. Score 0.9568, Min 0.4771, Max 0.9854): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.180, Min 0.039, Max 0.804), (Avg. Score 0.8203, Min 0.1971, Max 0.9611): 100%|██████████| 229/229 [00:40<00:00,  5.69it/s]
# --- EPOCH 89/100 ---
# train_batch (Avg. Loss 0.040, Min 0.013, Max 0.539), (Avg. Score 0.9598, Min 0.4608, Max 0.9868): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.193, Min 0.040, Max 0.989), (Avg. Score 0.8071, Min 0.0116, Max 0.9602): 100%|██████████| 229/229 [00:39<00:00,  5.84it/s]
# --- EPOCH 90/100 ---
# train_batch (Avg. Loss 0.041, Min 0.013, Max 0.537), (Avg. Score 0.9587, Min 0.4629, Max 0.9873): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.191, Min 0.027, Max 1.000), (Avg. Score 0.8088, Min 0.0000, Max 0.9729): 100%|██████████| 229/229 [00:40<00:00,  5.71it/s]
# --- EPOCH 91/100 ---
# train_batch (Avg. Loss 0.042, Min 0.014, Max 0.532), (Avg. Score 0.9577, Min 0.4682, Max 0.9859): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.215, Min 0.033, Max 1.000), (Avg. Score 0.7852, Min 0.0000, Max 0.9667): 100%|██████████| 229/229 [00:39<00:00,  5.75it/s]
# --- EPOCH 92/100 ---
# train_batch (Avg. Loss 0.041, Min 0.013, Max 0.528), (Avg. Score 0.9589, Min 0.4724, Max 0.9865): 100%|██████████| 1296/1296 [09:50<00:00,  2.15it/s]
# test_batch (Avg. Loss 0.200, Min 0.038, Max 1.000), (Avg. Score 0.8005, Min 0.0000, Max 0.9624): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 93/100 ---
# train_batch (Avg. Loss 0.039, Min 0.011, Max 0.528), (Avg. Score 0.9607, Min 0.4719, Max 0.9888): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.172, Min 0.036, Max 1.000), (Avg. Score 0.8281, Min 0.0000, Max 0.9643): 100%|██████████| 229/229 [00:40<00:00,  5.68it/s]
# --- EPOCH 94/100 ---
# train_batch (Avg. Loss 0.040, Min 0.013, Max 0.519), (Avg. Score 0.9600, Min 0.4810, Max 0.9871): 100%|██████████| 1296/1296 [09:50<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.186, Min 0.040, Max 1.000), (Avg. Score 0.8141, Min 0.0000, Max 0.9602): 100%|██████████| 229/229 [00:40<00:00,  5.72it/s]
# --- EPOCH 95/100 ---
# train_batch (Avg. Loss 0.039, Min 0.013, Max 0.593), (Avg. Score 0.9615, Min 0.4073, Max 0.9866): 100%|██████████| 1296/1296 [09:51<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.179, Min 0.045, Max 1.000), (Avg. Score 0.8213, Min 0.0000, Max 0.9554): 100%|██████████| 229/229 [00:39<00:00,  5.76it/s]
# --- EPOCH 96/100 ---
# train_batch (Avg. Loss 0.038, Min 0.012, Max 0.564), (Avg. Score 0.9616, Min 0.4358, Max 0.9879): 100%|██████████| 1296/1296 [09:50<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.178, Min 0.035, Max 1.000), (Avg. Score 0.8218, Min 0.0000, Max 0.9645): 100%|██████████| 229/229 [00:40<00:00,  6.84it/s]
# --- EPOCH 97/100 ---
# train_batch (Avg. Loss 0.041, Min 0.011, Max 0.543), (Avg. Score 0.9590, Min 0.4576, Max 0.9887): 100%|██████████| 1296/1296 [09:50<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.215, Min 0.038, Max 0.911), (Avg. Score 0.7850, Min 0.0899, Max 0.9621): 100%|██████████| 229/229 [00:39<00:00,  5.80it/s]
# --- EPOCH 98/100 ---
# train_batch (Avg. Loss 0.038, Min 0.013, Max 0.537), (Avg. Score 0.9624, Min 0.4629, Max 0.9866): 100%|██████████| 1296/1296 [09:51<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.286, Min 0.039, Max 0.995), (Avg. Score 0.7137, Min 0.0047, Max 0.9606): 100%|██████████| 229/229 [00:39<00:00,  6.59it/s]
# --- EPOCH 99/100 ---
# train_batch (Avg. Loss 0.038, Min 0.011, Max 0.547), (Avg. Score 0.9623, Min 0.4529, Max 0.9888): 100%|██████████| 1296/1296 [09:50<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.205, Min 0.042, Max 0.984), (Avg. Score 0.7948, Min 0.0078, Max 0.9580): 100%|██████████| 229/229 [00:39<00:00,  6.50it/s]
# --- EPOCH 100/100 ---
# train_batch (Avg. Loss 0.039, Min 0.014, Max 0.530), (Avg. Score 0.9611, Min 0.4700, Max 0.9863): 100%|██████████| 1296/1296 [09:50<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.227, Min 0.040, Max 1.000), (Avg. Score 0.7726, Min 0.0000, Max 0.9602): 100%|██████████| 229/229 [00:40<00:00,  6.57it/s]

# %%
from cs236605.plot import plot_fit
plot_fit(fit_res)
# Out:
# (<Figure size 1152x720 with 4 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa602ad43d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa602a2d090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6029f03d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa602a24a10>],
#        dtype=object))

# %%
print("Best dice score: %.2f" % fit_res.best_score)
# Out:
# Best dice score: 0.84

# %%
import matplotlib.pyplot as plt
plt.plot(fit_res.train_acc)
plt.plot(fit_res.test_acc)
plt.legend(['train score', 'test score'])
plt.show()
