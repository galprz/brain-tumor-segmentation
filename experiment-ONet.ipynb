# %% [markdown]
# # Experiment ONet
# #### Setup:
# **Dataset**: 3 different types of brain tumors <br>
# **Loss function**: Dice loss <br>
# **Optimizer**: Adam <br>
# **Model**: ONet

# %%
# Imports and training parameters
import torch
from torchvision.transforms import transforms
from src.datasets import BrainTumorDatasetMaskAndBoundingBox
from src.loss import  dice_loss
from src.metrics import dice_coeff
from src.models import ONet
from src.trainers import Trainer
torch.manual_seed(0)

num_epochs = 100
batch_size = 2
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Data preparation
# load the data see data_preprocessing notebook for more explanation

def normalize(x,  mean=470, std=None):
    mean_tansor = torch.ones_like(x) * mean
    x -= mean_tansor
    if std:
        x /= std
    return x

def preprocessing(image, mask, bounding_box):
    mask_transformer = transforms.Compose([
        transforms.ToTensor()    
    ])
    mask_tensor = mask_transformer(mask).float()
    bounding_box_tensor = torch.zeros_like(mask_tensor).squeeze()
    bounding_box_tensor[bounding_box[0]:bounding_box[1],
                      bounding_box[2]:bounding_box[3]] = 1
    bounding_box_tensor = bounding_box_tensor.unsqueeze(0)
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Lambda(lambda x: normalize(x))
    ])
    return (image_transformer(image).float(), bounding_box_tensor), mask_tensor

target_folder = './data/'
ds_train = BrainTumorDatasetMaskAndBoundingBox(root=target_folder, train=True, transform=preprocessing)
ds_test = BrainTumorDatasetMaskAndBoundingBox(root=target_folder, train=False, transform=preprocessing)
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=True)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size, shuffle=False)
# Out:
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script
# Data directory already exists.  if from some reason the data directory structure is wrong please remove the data dir and rerun this script

# %%
# Training and evaluation
model = ONet()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = dice_loss
success_metric = dice_coeff
trainer = Trainer(model, criterion, optimizer, dice_coeff, device, None)
fit_res = trainer.fit(dl_train, 
                      dl_test,
                      num_epochs= num_epochs,
                      checkpoints='src/saved_models/' + model.__class__.__name__ + "with_reg")
# Out:
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 0.828, Min 0.306, Max 1.000), (Avg. Score 0.1785, Min 0.0000, Max 0.7340): 100%|██████████| 1296/1296 [09:50<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.827, Min 0.425, Max 1.000), (Avg. Score 0.1869, Min 0.0000, Max 0.6647): 100%|██████████| 229/229 [00:38<00:00,  6.37it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 0.724, Min 0.203, Max 1.000), (Avg. Score 0.2791, Min 0.0000, Max 0.8234): 100%|██████████| 1296/1296 [09:51<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.819, Min 0.386, Max 1.000), (Avg. Score 0.1829, Min 0.0000, Max 0.6182): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 0.649, Min 0.122, Max 1.000), (Avg. Score 0.3517, Min 0.0000, Max 0.8788): 100%|██████████| 1296/1296 [09:52<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.740, Min 0.118, Max 1.000), (Avg. Score 0.2631, Min 0.0000, Max 0.8817): 100%|██████████| 229/229 [00:39<00:00,  5.86it/s]
# **** Checkpoint saved ****
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 0.582, Min 0.079, Max 1.000), (Avg. Score 0.4185, Min 0.0000, Max 0.9211): 100%|██████████| 1296/1296 [09:52<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.679, Min 0.143, Max 1.000), (Avg. Score 0.3202, Min 0.0000, Max 0.8586): 100%|██████████| 229/229 [00:38<00:00,  5.88it/s]
# **** Checkpoint saved ****
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 0.499, Min 0.061, Max 1.000), (Avg. Score 0.5009, Min 0.0000, Max 0.9407): 100%|██████████| 1296/1296 [09:52<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.569, Min 0.112, Max 1.000), (Avg. Score 0.4305, Min 0.0000, Max 0.8882): 100%|██████████| 229/229 [00:38<00:00,  5.95it/s]
# **** Checkpoint saved ****
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 0.464, Min 0.053, Max 1.000), (Avg. Score 0.5363, Min 0.0000, Max 0.9480): 100%|██████████| 1296/1296 [09:53<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.610, Min 0.093, Max 1.000), (Avg. Score 0.3895, Min 0.0000, Max 0.9063): 100%|██████████| 229/229 [00:39<00:00,  5.85it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 0.438, Min 0.046, Max 1.000), (Avg. Score 0.5622, Min 0.0000, Max 0.9553): 100%|██████████| 1296/1296 [09:53<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.544, Min 0.065, Max 1.000), (Avg. Score 0.4577, Min 0.0000, Max 0.9363): 100%|██████████| 229/229 [00:39<00:00,  6.77it/s]
# **** Checkpoint saved ****
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 0.395, Min 0.043, Max 1.000), (Avg. Score 0.6053, Min 0.0000, Max 0.9572): 100%|██████████| 1296/1296 [09:53<00:00,  2.23it/s]
# test_batch (Avg. Loss 0.417, Min 0.097, Max 0.999), (Avg. Score 0.5831, Min 0.0000, Max 0.9033): 100%|██████████| 229/229 [00:39<00:00,  5.78it/s]
# **** Checkpoint saved ****
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 0.364, Min 0.035, Max 1.000), (Avg. Score 0.6363, Min 0.0000, Max 0.9661): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.416, Min 0.071, Max 1.000), (Avg. Score 0.5852, Min 0.0000, Max 0.9295): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# **** Checkpoint saved ****
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 0.349, Min 0.032, Max 1.000), (Avg. Score 0.6518, Min 0.0000, Max 0.9684): 100%|██████████| 1296/1296 [09:55<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.369, Min 0.060, Max 1.000), (Avg. Score 0.6313, Min 0.0000, Max 0.9392): 100%|██████████| 229/229 [00:40<00:00,  5.68it/s]
# **** Checkpoint saved ****
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.324, Min 0.039, Max 1.000), (Avg. Score 0.6759, Min 0.0000, Max 0.9613): 100%|██████████| 1296/1296 [09:55<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.319, Min 0.063, Max 0.978), (Avg. Score 0.6814, Min 0.0211, Max 0.9366): 100%|██████████| 229/229 [00:39<00:00,  5.76it/s]
# **** Checkpoint saved ****
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 0.311, Min 0.031, Max 0.970), (Avg. Score 0.6897, Min 0.0287, Max 0.9690): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.542, Min 0.064, Max 1.000), (Avg. Score 0.4581, Min 0.0000, Max 0.9356): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 0.293, Min 0.030, Max 1.000), (Avg. Score 0.7073, Min 0.0000, Max 0.9701): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.358, Min 0.049, Max 0.857), (Avg. Score 0.6429, Min 0.1439, Max 0.9513): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.279, Min 0.027, Max 1.000), (Avg. Score 0.7213, Min 0.0000, Max 0.9743): 100%|██████████| 1296/1296 [09:55<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.231, Min 0.049, Max 0.979), (Avg. Score 0.7689, Min 0.0207, Max 0.9505): 100%|██████████| 229/229 [00:40<00:00,  5.71it/s]
# **** Checkpoint saved ****
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.270, Min 0.032, Max 1.000), (Avg. Score 0.7303, Min 0.0000, Max 0.9684): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.253, Min 0.063, Max 0.957), (Avg. Score 0.7476, Min 0.0419, Max 0.9364): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.260, Min 0.026, Max 0.946), (Avg. Score 0.7404, Min 0.0539, Max 0.9737): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.274, Min 0.052, Max 0.981), (Avg. Score 0.7263, Min 0.0185, Max 0.9469): 100%|██████████| 229/229 [00:39<00:00,  5.73it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.247, Min 0.022, Max 0.893), (Avg. Score 0.7532, Min 0.1075, Max 0.9783): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.270, Min 0.042, Max 0.972), (Avg. Score 0.7296, Min 0.0277, Max 0.9580): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.236, Min 0.030, Max 0.917), (Avg. Score 0.7641, Min 0.0833, Max 0.9698): 100%|██████████| 1296/1296 [09:56<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.238, Min 0.040, Max 1.000), (Avg. Score 0.7622, Min 0.0000, Max 0.9597): 100%|██████████| 229/229 [00:39<00:00,  5.78it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.220, Min 0.027, Max 0.947), (Avg. Score 0.7806, Min 0.0524, Max 0.9728): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.234, Min 0.049, Max 0.947), (Avg. Score 0.7658, Min 0.0512, Max 0.9508): 100%|██████████| 229/229 [00:40<00:00,  5.70it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.219, Min 0.020, Max 1.000), (Avg. Score 0.7813, Min 0.0000, Max 0.9800): 100%|██████████| 1296/1296 [09:56<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.208, Min 0.045, Max 0.816), (Avg. Score 0.7925, Min 0.1834, Max 0.9561): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# **** Checkpoint saved ****
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.207, Min 0.021, Max 1.000), (Avg. Score 0.7935, Min 0.0000, Max 0.9786): 100%|██████████| 1296/1296 [09:56<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.224, Min 0.050, Max 1.000), (Avg. Score 0.7762, Min 0.0000, Max 0.9492): 100%|██████████| 229/229 [00:40<00:00,  6.27it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.202, Min 0.025, Max 0.846), (Avg. Score 0.7978, Min 0.1454, Max 0.9754): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.243, Min 0.036, Max 1.000), (Avg. Score 0.7571, Min 0.0000, Max 0.9644): 100%|██████████| 229/229 [00:40<00:00,  6.06it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.188, Min 0.026, Max 0.772), (Avg. Score 0.8122, Min 0.2285, Max 0.9736): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.211, Min 0.045, Max 0.990), (Avg. Score 0.7890, Min 0.0000, Max 0.9549): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.188, Min 0.027, Max 0.878), (Avg. Score 0.8118, Min 0.1225, Max 0.9733): 100%|██████████| 1296/1296 [09:55<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.200, Min 0.043, Max 1.000), (Avg. Score 0.7996, Min 0.0000, Max 0.9578): 100%|██████████| 229/229 [00:39<00:00,  5.79it/s]
# **** Checkpoint saved ****
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.180, Min 0.027, Max 1.000), (Avg. Score 0.8204, Min 0.0000, Max 0.9735): 100%|██████████| 1296/1296 [09:56<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.257, Min 0.040, Max 1.000), (Avg. Score 0.7430, Min 0.0000, Max 0.9595): 100%|██████████| 229/229 [00:39<00:00,  6.44it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.170, Min 0.022, Max 0.875), (Avg. Score 0.8300, Min 0.1247, Max 0.9783): 100%|██████████| 1296/1296 [09:55<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.191, Min 0.036, Max 0.669), (Avg. Score 0.8093, Min 0.3307, Max 0.9640): 100%|██████████| 229/229 [00:40<00:00,  6.10it/s]
# **** Checkpoint saved ****
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.166, Min 0.026, Max 0.731), (Avg. Score 0.8336, Min 0.2692, Max 0.9742): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.243, Min 0.043, Max 1.000), (Avg. Score 0.7567, Min 0.0000, Max 0.9573): 100%|██████████| 229/229 [00:39<00:00,  6.03it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.164, Min 0.023, Max 0.870), (Avg. Score 0.8363, Min 0.1300, Max 0.9773): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.226, Min 0.035, Max 0.790), (Avg. Score 0.7743, Min 0.2096, Max 0.9647): 100%|██████████| 229/229 [00:41<00:00,  5.57it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.162, Min 0.019, Max 0.708), (Avg. Score 0.8380, Min 0.2917, Max 0.9807): 100%|██████████| 1296/1296 [09:55<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.205, Min 0.032, Max 1.000), (Avg. Score 0.7947, Min 0.0000, Max 0.9680): 100%|██████████| 229/229 [00:39<00:00,  5.83it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.154, Min 0.022, Max 0.769), (Avg. Score 0.8461, Min 0.2308, Max 0.9783): 100%|██████████| 1296/1296 [09:55<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.185, Min 0.037, Max 0.976), (Avg. Score 0.8153, Min 0.0206, Max 0.9631): 100%|██████████| 229/229 [00:40<00:00,  5.68it/s]
# **** Checkpoint saved ****
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.151, Min 0.026, Max 0.691), (Avg. Score 0.8493, Min 0.3086, Max 0.9743): 100%|██████████| 1296/1296 [09:55<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.184, Min 0.037, Max 0.764), (Avg. Score 0.8157, Min 0.2364, Max 0.9627): 100%|██████████| 229/229 [00:40<00:00,  5.72it/s]
# **** Checkpoint saved ****
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.145, Min 0.024, Max 0.688), (Avg. Score 0.8550, Min 0.3122, Max 0.9757): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.199, Min 0.036, Max 1.000), (Avg. Score 0.8006, Min 0.0000, Max 0.9644): 100%|██████████| 229/229 [00:39<00:00,  6.31it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.142, Min 0.024, Max 0.680), (Avg. Score 0.8584, Min 0.3203, Max 0.9761): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.178, Min 0.044, Max 0.912), (Avg. Score 0.8217, Min 0.0885, Max 0.9555): 100%|██████████| 229/229 [00:40<00:00,  6.58it/s]
# **** Checkpoint saved ****
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.128, Min 0.024, Max 0.707), (Avg. Score 0.8720, Min 0.2927, Max 0.9758): 100%|██████████| 1296/1296 [09:55<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.184, Min 0.035, Max 1.000), (Avg. Score 0.8157, Min 0.0000, Max 0.9649): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.133, Min 0.019, Max 0.718), (Avg. Score 0.8671, Min 0.2819, Max 0.9807): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.179, Min 0.040, Max 1.000), (Avg. Score 0.8212, Min 0.0000, Max 0.9602): 100%|██████████| 229/229 [00:39<00:00,  5.73it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.128, Min 0.027, Max 0.625), (Avg. Score 0.8725, Min 0.3749, Max 0.9734): 100%|██████████| 1296/1296 [09:55<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.176, Min 0.040, Max 1.000), (Avg. Score 0.8242, Min 0.0000, Max 0.9598): 100%|██████████| 229/229 [00:40<00:00,  5.72it/s]
# **** Checkpoint saved ****
# --- EPOCH 37/100 ---
# train_batch (Avg. Loss 0.123, Min 0.018, Max 0.726), (Avg. Score 0.8770, Min 0.2739, Max 0.9821): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.223, Min 0.045, Max 0.659), (Avg. Score 0.7772, Min 0.3411, Max 0.9550): 100%|██████████| 229/229 [00:40<00:00,  6.67it/s]
# --- EPOCH 38/100 ---
# train_batch (Avg. Loss 0.122, Min 0.024, Max 0.661), (Avg. Score 0.8782, Min 0.3405, Max 0.9763): 100%|██████████| 1296/1296 [09:55<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.192, Min 0.035, Max 1.000), (Avg. Score 0.8085, Min 0.0000, Max 0.9646): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 39/100 ---
# train_batch (Avg. Loss 0.118, Min 0.021, Max 0.602), (Avg. Score 0.8817, Min 0.3983, Max 0.9786): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.172, Min 0.037, Max 1.000), (Avg. Score 0.8285, Min 0.0000, Max 0.9626): 100%|██████████| 229/229 [00:40<00:00,  5.69it/s]
# **** Checkpoint saved ****
# --- EPOCH 40/100 ---
# train_batch (Avg. Loss 0.118, Min 0.018, Max 0.695), (Avg. Score 0.8823, Min 0.3052, Max 0.9820): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.182, Min 0.036, Max 1.000), (Avg. Score 0.8185, Min 0.0000, Max 0.9643): 100%|██████████| 229/229 [00:40<00:00,  5.79it/s]
# --- EPOCH 41/100 ---
# train_batch (Avg. Loss 0.110, Min 0.022, Max 0.601), (Avg. Score 0.8896, Min 0.3992, Max 0.9782): 100%|██████████| 1296/1296 [09:55<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.173, Min 0.041, Max 1.000), (Avg. Score 0.8266, Min 0.0000, Max 0.9592): 100%|██████████| 229/229 [00:40<00:00,  5.71it/s]
# --- EPOCH 42/100 ---
# train_batch (Avg. Loss 0.107, Min 0.018, Max 0.755), (Avg. Score 0.8928, Min 0.2453, Max 0.9817): 100%|██████████| 1296/1296 [09:55<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.223, Min 0.036, Max 1.000), (Avg. Score 0.7770, Min 0.0000, Max 0.9643): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 43/100 ---
# train_batch (Avg. Loss 0.109, Min 0.022, Max 0.754), (Avg. Score 0.8906, Min 0.2457, Max 0.9781): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.175, Min 0.038, Max 1.000), (Avg. Score 0.8245, Min 0.0000, Max 0.9618): 100%|██████████| 229/229 [00:39<00:00,  6.50it/s]
# --- EPOCH 44/100 ---
# train_batch (Avg. Loss 0.102, Min 0.022, Max 0.680), (Avg. Score 0.8982, Min 0.3203, Max 0.9781): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.188, Min 0.040, Max 0.892), (Avg. Score 0.8119, Min 0.1032, Max 0.9604): 100%|██████████| 229/229 [00:39<00:00,  6.85it/s]
# --- EPOCH 45/100 ---
# train_batch (Avg. Loss 0.096, Min 0.021, Max 0.613), (Avg. Score 0.9036, Min 0.3869, Max 0.9789): 100%|██████████| 1296/1296 [09:57<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.159, Min 0.041, Max 0.944), (Avg. Score 0.8407, Min 0.0557, Max 0.9587): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# **** Checkpoint saved ****
# --- EPOCH 46/100 ---
# train_batch (Avg. Loss 0.104, Min 0.019, Max 0.644), (Avg. Score 0.8958, Min 0.3550, Max 0.9810): 100%|██████████| 1296/1296 [09:56<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.170, Min 0.031, Max 0.839), (Avg. Score 0.8304, Min 0.1609, Max 0.9688): 100%|██████████| 229/229 [00:40<00:00,  5.66it/s]
# --- EPOCH 47/100 ---
# train_batch (Avg. Loss 0.096, Min 0.021, Max 0.580), (Avg. Score 0.9040, Min 0.4197, Max 0.9794): 100%|██████████| 1296/1296 [09:56<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.287, Min 0.029, Max 1.000), (Avg. Score 0.7131, Min 0.0000, Max 0.9716): 100%|██████████| 229/229 [00:40<00:00,  5.72it/s]
# --- EPOCH 48/100 ---
# train_batch (Avg. Loss 0.091, Min 0.020, Max 0.551), (Avg. Score 0.9090, Min 0.4496, Max 0.9796): 100%|██████████| 1296/1296 [09:56<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.189, Min 0.041, Max 0.943), (Avg. Score 0.8113, Min 0.0583, Max 0.9589): 100%|██████████| 229/229 [00:40<00:00,  6.00it/s]
# --- EPOCH 49/100 ---
# train_batch (Avg. Loss 0.092, Min 0.021, Max 0.628), (Avg. Score 0.9080, Min 0.3718, Max 0.9790): 100%|██████████| 1296/1296 [09:57<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.183, Min 0.038, Max 1.000), (Avg. Score 0.8167, Min 0.0000, Max 0.9613): 100%|██████████| 229/229 [00:39<00:00,  5.76it/s]
# --- EPOCH 50/100 ---
# train_batch (Avg. Loss 0.086, Min 0.021, Max 0.575), (Avg. Score 0.9136, Min 0.4254, Max 0.9795): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.170, Min 0.039, Max 0.967), (Avg. Score 0.8300, Min 0.0342, Max 0.9606): 100%|██████████| 229/229 [00:40<00:00,  5.61it/s]
# --- EPOCH 51/100 ---
# train_batch (Avg. Loss 0.089, Min 0.021, Max 0.597), (Avg. Score 0.9105, Min 0.4027, Max 0.9794): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.165, Min 0.039, Max 1.000), (Avg. Score 0.8349, Min 0.0000, Max 0.9610): 100%|██████████| 229/229 [00:40<00:00,  5.59it/s]
# --- EPOCH 52/100 ---
# train_batch (Avg. Loss 0.091, Min 0.020, Max 0.756), (Avg. Score 0.9090, Min 0.2438, Max 0.9801): 100%|██████████| 1296/1296 [09:56<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.171, Min 0.037, Max 0.684), (Avg. Score 0.8291, Min 0.3149, Max 0.9631): 100%|██████████| 229/229 [00:40<00:00,  5.63it/s]
# --- EPOCH 53/100 ---
# train_batch (Avg. Loss 0.084, Min 0.021, Max 0.617), (Avg. Score 0.9160, Min 0.3831, Max 0.9792): 100%|██████████| 1296/1296 [09:58<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.181, Min 0.037, Max 1.000), (Avg. Score 0.8189, Min 0.0000, Max 0.9624): 100%|██████████| 229/229 [00:40<00:00,  5.70it/s]
# --- EPOCH 54/100 ---
# train_batch (Avg. Loss 0.079, Min 0.020, Max 0.553), (Avg. Score 0.9206, Min 0.4471, Max 0.9801): 100%|██████████| 1296/1296 [09:57<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.173, Min 0.038, Max 0.800), (Avg. Score 0.8275, Min 0.2054, Max 0.9624): 100%|██████████| 229/229 [00:40<00:00,  5.71it/s]
# --- EPOCH 55/100 ---
# train_batch (Avg. Loss 0.079, Min 0.022, Max 0.659), (Avg. Score 0.9215, Min 0.3412, Max 0.9783): 100%|██████████| 1296/1296 [09:57<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.202, Min 0.039, Max 1.000), (Avg. Score 0.7978, Min 0.0000, Max 0.9612): 100%|██████████| 229/229 [00:40<00:00,  5.66it/s]
# --- EPOCH 56/100 ---
# train_batch (Avg. Loss 0.074, Min 0.018, Max 0.594), (Avg. Score 0.9260, Min 0.4061, Max 0.9824): 100%|██████████| 1296/1296 [09:58<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.160, Min 0.036, Max 1.000), (Avg. Score 0.8405, Min 0.0000, Max 0.9646): 100%|██████████| 229/229 [00:40<00:00,  5.66it/s]
# --- EPOCH 57/100 ---
# train_batch (Avg. Loss 0.084, Min 0.018, Max 0.644), (Avg. Score 0.9162, Min 0.3557, Max 0.9818): 100%|██████████| 1296/1296 [09:55<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.150, Min 0.031, Max 0.873), (Avg. Score 0.8496, Min 0.1285, Max 0.9689): 100%|██████████| 229/229 [00:40<00:00,  5.69it/s]
# **** Checkpoint saved ****
# --- EPOCH 58/100 ---
# train_batch (Avg. Loss 0.071, Min 0.019, Max 0.608), (Avg. Score 0.9292, Min 0.3919, Max 0.9808): 100%|██████████| 1296/1296 [09:55<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.152, Min 0.037, Max 0.656), (Avg. Score 0.8483, Min 0.3448, Max 0.9629): 100%|██████████| 229/229 [00:40<00:00,  6.07it/s]
# --- EPOCH 59/100 ---
# train_batch (Avg. Loss 0.070, Min 0.018, Max 0.556), (Avg. Score 0.9300, Min 0.4445, Max 0.9821): 100%|██████████| 1296/1296 [09:55<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.171, Min 0.036, Max 1.000), (Avg. Score 0.8287, Min 0.0000, Max 0.9642): 100%|██████████| 229/229 [00:39<00:00,  5.73it/s]
# --- EPOCH 60/100 ---
# train_batch (Avg. Loss 0.068, Min 0.017, Max 0.634), (Avg. Score 0.9322, Min 0.3662, Max 0.9829): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.167, Min 0.039, Max 1.000), (Avg. Score 0.8328, Min 0.0000, Max 0.9612): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 61/100 ---
# train_batch (Avg. Loss 0.072, Min 0.017, Max 0.553), (Avg. Score 0.9280, Min 0.4473, Max 0.9829): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.189, Min 0.037, Max 1.000), (Avg. Score 0.8107, Min 0.0000, Max 0.9626): 100%|██████████| 229/229 [00:41<00:00,  5.59it/s]
# --- EPOCH 62/100 ---
# train_batch (Avg. Loss 0.071, Min 0.021, Max 0.583), (Avg. Score 0.9286, Min 0.4174, Max 0.9787): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.162, Min 0.042, Max 0.914), (Avg. Score 0.8384, Min 0.0887, Max 0.9581): 100%|██████████| 229/229 [00:40<00:00,  5.69it/s]
# --- EPOCH 63/100 ---
# train_batch (Avg. Loss 0.064, Min 0.018, Max 0.536), (Avg. Score 0.9360, Min 0.4643, Max 0.9816): 100%|██████████| 1296/1296 [09:57<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.167, Min 0.036, Max 0.770), (Avg. Score 0.8325, Min 0.2300, Max 0.9638): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 64/100 ---
# train_batch (Avg. Loss 0.065, Min 0.019, Max 1.000), (Avg. Score 0.9351, Min 0.0000, Max 0.9814): 100%|██████████| 1296/1296 [09:57<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.322, Min 0.038, Max 1.000), (Avg. Score 0.6776, Min 0.0000, Max 0.9621): 100%|██████████| 229/229 [00:39<00:00,  5.82it/s]
# --- EPOCH 65/100 ---
# train_batch (Avg. Loss 0.069, Min 0.019, Max 0.572), (Avg. Score 0.9308, Min 0.4278, Max 0.9810): 100%|██████████| 1296/1296 [09:56<00:00,  2.15it/s]
# test_batch (Avg. Loss 0.163, Min 0.039, Max 1.000), (Avg. Score 0.8367, Min 0.0000, Max 0.9610): 100%|██████████| 229/229 [00:40<00:00,  5.66it/s]
# --- EPOCH 66/100 ---
# train_batch (Avg. Loss 0.061, Min 0.018, Max 0.634), (Avg. Score 0.9385, Min 0.3657, Max 0.9822): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.166, Min 0.039, Max 1.000), (Avg. Score 0.8338, Min 0.0000, Max 0.9605): 100%|██████████| 229/229 [00:40<00:00,  6.27it/s]
# --- EPOCH 67/100 ---
# train_batch (Avg. Loss 0.059, Min 0.014, Max 0.553), (Avg. Score 0.9410, Min 0.4467, Max 0.9858): 100%|██████████| 1296/1296 [09:56<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.184, Min 0.038, Max 1.000), (Avg. Score 0.8158, Min 0.0000, Max 0.9623): 100%|██████████| 229/229 [00:39<00:00,  5.75it/s]
# --- EPOCH 68/100 ---
# train_batch (Avg. Loss 0.059, Min 0.017, Max 0.541), (Avg. Score 0.9406, Min 0.4594, Max 0.9829): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.179, Min 0.042, Max 1.000), (Avg. Score 0.8210, Min 0.0000, Max 0.9586): 100%|██████████| 229/229 [00:39<00:00,  5.77it/s]
# --- EPOCH 69/100 ---
# train_batch (Avg. Loss 0.059, Min 0.018, Max 0.625), (Avg. Score 0.9408, Min 0.3748, Max 0.9816): 100%|██████████| 1296/1296 [09:55<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.174, Min 0.035, Max 1.000), (Avg. Score 0.8264, Min 0.0000, Max 0.9648): 100%|██████████| 229/229 [00:40<00:00,  5.59it/s]
# --- EPOCH 70/100 ---
# train_batch (Avg. Loss 0.062, Min 0.018, Max 0.565), (Avg. Score 0.9384, Min 0.4348, Max 0.9823): 100%|██████████| 1296/1296 [09:55<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.155, Min 0.036, Max 1.000), (Avg. Score 0.8455, Min 0.0000, Max 0.9640): 100%|██████████| 229/229 [00:41<00:00,  5.53it/s]
# --- EPOCH 71/100 ---
# train_batch (Avg. Loss 0.056, Min 0.017, Max 0.534), (Avg. Score 0.9443, Min 0.4662, Max 0.9833): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.210, Min 0.033, Max 0.889), (Avg. Score 0.7897, Min 0.1113, Max 0.9674): 100%|██████████| 229/229 [00:40<00:00,  5.61it/s]
# --- EPOCH 72/100 ---
# train_batch (Avg. Loss 0.056, Min 0.018, Max 0.547), (Avg. Score 0.9438, Min 0.4534, Max 0.9822): 100%|██████████| 1296/1296 [09:55<00:00,  2.14it/s]
# test_batch (Avg. Loss 0.186, Min 0.038, Max 1.000), (Avg. Score 0.8137, Min 0.0000, Max 0.9623): 100%|██████████| 229/229 [00:40<00:00,  5.59it/s]
# --- EPOCH 73/100 ---
# train_batch (Avg. Loss 0.054, Min 0.017, Max 0.541), (Avg. Score 0.9455, Min 0.4584, Max 0.9834): 100%|██████████| 1296/1296 [09:55<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.153, Min 0.036, Max 1.000), (Avg. Score 0.8470, Min 0.0000, Max 0.9640): 100%|██████████| 229/229 [00:40<00:00,  5.59it/s]
# --- EPOCH 74/100 ---
# train_batch (Avg. Loss 0.052, Min 0.017, Max 0.583), (Avg. Score 0.9481, Min 0.4171, Max 0.9830): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.158, Min 0.036, Max 1.000), (Avg. Score 0.8418, Min 0.0000, Max 0.9634): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 75/100 ---
# train_batch (Avg. Loss 0.053, Min 0.013, Max 0.544), (Avg. Score 0.9466, Min 0.4562, Max 0.9873): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.163, Min 0.044, Max 0.800), (Avg. Score 0.8371, Min 0.2005, Max 0.9562): 100%|██████████| 229/229 [00:40<00:00,  5.92it/s]
# --- EPOCH 76/100 ---
# train_batch (Avg. Loss 0.050, Min 0.013, Max 0.534), (Avg. Score 0.9497, Min 0.4658, Max 0.9868): 100%|██████████| 1296/1296 [09:55<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.169, Min 0.037, Max 1.000), (Avg. Score 0.8312, Min 0.0000, Max 0.9630): 100%|██████████| 229/229 [00:40<00:00,  5.62it/s]
# --- EPOCH 77/100 ---
# train_batch (Avg. Loss 0.055, Min 0.016, Max 0.528), (Avg. Score 0.9454, Min 0.4718, Max 0.9843): 100%|██████████| 1296/1296 [09:55<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.183, Min 0.038, Max 1.000), (Avg. Score 0.8168, Min 0.0000, Max 0.9622): 100%|██████████| 229/229 [00:40<00:00,  5.60it/s]
# --- EPOCH 78/100 ---
# train_batch (Avg. Loss 0.055, Min 0.017, Max 0.534), (Avg. Score 0.9450, Min 0.4664, Max 0.9830): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.162, Min 0.034, Max 1.000), (Avg. Score 0.8377, Min 0.0000, Max 0.9664): 100%|██████████| 229/229 [00:40<00:00,  5.68it/s]
# --- EPOCH 79/100 ---
# train_batch (Avg. Loss 0.046, Min 0.014, Max 0.542), (Avg. Score 0.9542, Min 0.4584, Max 0.9861): 100%|██████████| 1296/1296 [09:56<00:00,  2.15it/s]
# test_batch (Avg. Loss 0.158, Min 0.035, Max 1.000), (Avg. Score 0.8422, Min 0.0000, Max 0.9647): 100%|██████████| 229/229 [00:40<00:00,  5.59it/s]
# --- EPOCH 80/100 ---
# train_batch (Avg. Loss 0.046, Min 0.016, Max 0.540), (Avg. Score 0.9539, Min 0.4598, Max 0.9844): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.158, Min 0.040, Max 1.000), (Avg. Score 0.8422, Min 0.0000, Max 0.9599): 100%|██████████| 229/229 [00:40<00:00,  6.43it/s]
# --- EPOCH 81/100 ---
# train_batch (Avg. Loss 0.048, Min 0.017, Max 0.536), (Avg. Score 0.9524, Min 0.4640, Max 0.9834): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.154, Min 0.040, Max 1.000), (Avg. Score 0.8456, Min 0.0000, Max 0.9598): 100%|██████████| 229/229 [00:40<00:00,  5.67it/s]
# --- EPOCH 82/100 ---
# train_batch (Avg. Loss 0.055, Min 0.015, Max 0.572), (Avg. Score 0.9449, Min 0.4281, Max 0.9853): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.163, Min 0.040, Max 1.000), (Avg. Score 0.8368, Min 0.0000, Max 0.9598): 100%|██████████| 229/229 [00:41<00:00,  5.58it/s]
# --- EPOCH 83/100 ---
# train_batch (Avg. Loss 0.045, Min 0.015, Max 0.527), (Avg. Score 0.9546, Min 0.4723, Max 0.9853): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.161, Min 0.036, Max 1.000), (Avg. Score 0.8387, Min 0.0000, Max 0.9644): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 84/100 ---
# train_batch (Avg. Loss 0.044, Min 0.017, Max 0.535), (Avg. Score 0.9559, Min 0.4649, Max 0.9834): 100%|██████████| 1296/1296 [09:56<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.187, Min 0.032, Max 1.000), (Avg. Score 0.8128, Min 0.0000, Max 0.9676): 100%|██████████| 229/229 [00:40<00:00,  5.66it/s]
# --- EPOCH 85/100 ---
# train_batch (Avg. Loss 0.050, Min 0.012, Max 0.526), (Avg. Score 0.9502, Min 0.4742, Max 0.9879): 100%|██████████| 1296/1296 [09:56<00:00,  2.14it/s]
# test_batch (Avg. Loss 0.163, Min 0.035, Max 1.000), (Avg. Score 0.8368, Min 0.0000, Max 0.9649): 100%|██████████| 229/229 [00:41<00:00,  5.56it/s]
# --- EPOCH 86/100 ---
# train_batch (Avg. Loss 0.043, Min 0.015, Max 0.516), (Avg. Score 0.9566, Min 0.4840, Max 0.9854): 100%|██████████| 1296/1296 [09:55<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.170, Min 0.033, Max 1.000), (Avg. Score 0.8299, Min 0.0000, Max 0.9670): 100%|██████████| 229/229 [00:39<00:00,  5.74it/s]
# --- EPOCH 87/100 ---
# train_batch (Avg. Loss 0.043, Min 0.015, Max 0.525), (Avg. Score 0.9573, Min 0.4754, Max 0.9850): 100%|██████████| 1296/1296 [09:54<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.151, Min 0.038, Max 0.860), (Avg. Score 0.8495, Min 0.1439, Max 0.9622): 100%|██████████| 229/229 [00:40<00:00,  6.29it/s]
# --- EPOCH 88/100 ---
# train_batch (Avg. Loss 0.043, Min 0.013, Max 0.534), (Avg. Score 0.9573, Min 0.4663, Max 0.9871): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.158, Min 0.040, Max 1.000), (Avg. Score 0.8417, Min 0.0000, Max 0.9606): 100%|██████████| 229/229 [00:40<00:00,  5.65it/s]
# --- EPOCH 89/100 ---
# train_batch (Avg. Loss 0.042, Min 0.015, Max 0.522), (Avg. Score 0.9578, Min 0.4779, Max 0.9847): 100%|██████████| 1296/1296 [09:56<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.168, Min 0.038, Max 1.000), (Avg. Score 0.8319, Min 0.0000, Max 0.9624): 100%|██████████| 229/229 [00:41<00:00,  5.52it/s]
# --- EPOCH 90/100 ---
# train_batch (Avg. Loss 0.042, Min 0.014, Max 0.524), (Avg. Score 0.9578, Min 0.4756, Max 0.9862): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.167, Min 0.036, Max 1.000), (Avg. Score 0.8334, Min 0.0000, Max 0.9639): 100%|██████████| 229/229 [00:41<00:00,  5.49it/s]
# --- EPOCH 91/100 ---
# train_batch (Avg. Loss 0.041, Min 0.015, Max 0.527), (Avg. Score 0.9587, Min 0.4730, Max 0.9853): 100%|██████████| 1296/1296 [09:56<00:00,  2.16it/s]
# test_batch (Avg. Loss 0.151, Min 0.034, Max 0.758), (Avg. Score 0.8491, Min 0.2433, Max 0.9658): 100%|██████████| 229/229 [00:41<00:00,  5.58it/s]
# --- EPOCH 92/100 ---
# train_batch (Avg. Loss 0.041, Min 0.013, Max 0.527), (Avg. Score 0.9586, Min 0.4734, Max 0.9876): 100%|██████████| 1296/1296 [09:56<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.156, Min 0.037, Max 1.000), (Avg. Score 0.8438, Min 0.0000, Max 0.9626): 100%|██████████| 229/229 [00:41<00:00,  5.52it/s]
# --- EPOCH 93/100 ---
# train_batch (Avg. Loss 0.042, Min 0.013, Max 0.543), (Avg. Score 0.9584, Min 0.4571, Max 0.9870): 100%|██████████| 1296/1296 [09:57<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.190, Min 0.027, Max 1.000), (Avg. Score 0.8101, Min 0.0000, Max 0.9733): 100%|██████████| 229/229 [00:41<00:00,  6.41it/s]
# --- EPOCH 94/100 ---
# train_batch (Avg. Loss 0.047, Min 0.013, Max 0.777), (Avg. Score 0.9535, Min 0.2232, Max 0.9869): 100%|██████████| 1296/1296 [09:57<00:00,  2.15it/s]
# test_batch (Avg. Loss 0.219, Min 0.037, Max 1.000), (Avg. Score 0.7812, Min 0.0000, Max 0.9633): 100%|██████████| 229/229 [00:41<00:00,  5.58it/s]
# --- EPOCH 95/100 ---
# train_batch (Avg. Loss 0.039, Min 0.014, Max 0.533), (Avg. Score 0.9609, Min 0.4663, Max 0.9857): 100%|██████████| 1296/1296 [09:56<00:00,  2.14it/s]
# test_batch (Avg. Loss 0.155, Min 0.032, Max 1.000), (Avg. Score 0.8450, Min 0.0000, Max 0.9687): 100%|██████████| 229/229 [00:40<00:00,  5.64it/s]
# --- EPOCH 96/100 ---
# train_batch (Avg. Loss 0.037, Min 0.014, Max 0.525), (Avg. Score 0.9632, Min 0.4753, Max 0.9859): 100%|██████████| 1296/1296 [09:57<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.155, Min 0.032, Max 1.000), (Avg. Score 0.8450, Min 0.0000, Max 0.9675): 100%|██████████| 229/229 [00:42<00:00,  5.87it/s]
# --- EPOCH 97/100 ---
# train_batch (Avg. Loss 0.038, Min 0.014, Max 0.528), (Avg. Score 0.9621, Min 0.4722, Max 0.9855): 100%|██████████| 1296/1296 [09:57<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.153, Min 0.037, Max 0.938), (Avg. Score 0.8470, Min 0.0619, Max 0.9634): 100%|██████████| 229/229 [00:41<00:00,  6.15it/s]
# --- EPOCH 98/100 ---
# train_batch (Avg. Loss 0.039, Min 0.013, Max 0.526), (Avg. Score 0.9611, Min 0.4745, Max 0.9867): 100%|██████████| 1296/1296 [09:57<00:00,  2.19it/s]
# test_batch (Avg. Loss 0.176, Min 0.039, Max 1.000), (Avg. Score 0.8243, Min 0.0000, Max 0.9610): 100%|██████████| 229/229 [00:41<00:00,  5.50it/s]
# --- EPOCH 99/100 ---
# train_batch (Avg. Loss 0.038, Min 0.015, Max 0.518), (Avg. Score 0.9618, Min 0.4823, Max 0.9855): 100%|██████████| 1296/1296 [09:57<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.174, Min 0.034, Max 1.000), (Avg. Score 0.8261, Min 0.0000, Max 0.9660): 100%|██████████| 229/229 [00:40<00:00,  5.62it/s]
# --- EPOCH 100/100 ---
# train_batch (Avg. Loss 0.039, Min 0.014, Max 0.529), (Avg. Score 0.9615, Min 0.4710, Max 0.9859): 100%|██████████| 1296/1296 [09:56<00:00,  2.18it/s]
# test_batch (Avg. Loss 0.168, Min 0.038, Max 0.735), (Avg. Score 0.8323, Min 0.2662, Max 0.9624): 100%|██████████| 229/229 [00:40<00:00,  6.65it/s]

# %%
from cs236605.plot import plot_fit
plot_fit(fit_res)
# Out:
# (<Figure size 1152x720 with 4 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9394423690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f93943dde50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9394392690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9394348cd0>],
#        dtype=object))

# %%
print("Best dice score: %.2f" % fit_res.best_score)
# Out:
# Best dice score: 0.85

# %%
import matplotlib.pyplot as plt
plt.plot(fit_res.train_acc)
plt.plot(fit_res.test_acc)
plt.legend(['train score', 'test score'])
plt.show()
